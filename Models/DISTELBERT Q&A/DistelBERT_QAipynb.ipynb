# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/My Drive/Distelbert
# Out:
# /content/drive/My Drive/Distelbert

# %%
# !pip install transformers
# Out:
# Requirement already satisfied: transformers in /usr/local/lib/python3.10/dist-packages (4.41.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers) (3.14.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.23.0 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.23.1)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (1.25.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from transformers) (24.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (6.0.1)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (2023.12.25)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from transformers) (2.31.0)
# Requirement already satisfied: tokenizers<0.20,>=0.19 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.19.1)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.4.3)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.10/dist-packages (from transformers) (4.66.4)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.23.0->transformers) (2023.6.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.23.0->transformers) (4.11.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2024.2.2)

# %%
pip install transformers[torch]
# Out:
# Requirement already satisfied: transformers[torch] in /usr/local/lib/python3.10/dist-packages (4.41.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers[torch]) (3.14.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.23.0 in /usr/local/lib/python3.10/dist-packages (from transformers[torch]) (0.23.1)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from transformers[torch]) (1.25.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from transformers[torch]) (24.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers[torch]) (6.0.1)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers[torch]) (2023.12.25)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from transformers[torch]) (2.31.0)
# Requirement already satisfied: tokenizers<0.20,>=0.19 in /usr/local/lib/python3.10/dist-packages (from transformers[torch]) (0.19.1)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.10/dist-packages (from transformers[torch]) (0.4.3)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.10/dist-packages (from transformers[torch]) (4.66.4)
# Requirement already satisfied: torch in /usr/local/lib/python3.10/dist-packages (from transformers[torch]) (2.3.0+cu121)
# Collecting accelerate>=0.21.0 (from transformers[torch])
#   Downloading accelerate-0.30.1-py3-none-any.whl (302 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 302.6/302.6 kB 8.0 MB/s eta 0:00:00
# Requirement already satisfied: psutil in /usr/local/lib/python3.10/dist-packages (from accelerate>=0.21.0->transformers[torch]) (5.9.5)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.23.0->transformers[torch]) (2023.6.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.23.0->transformers[torch]) (4.11.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch->transformers[torch]) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch->transformers[torch]) (3.3)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch->transformers[torch]) (3.1.4)
# Collecting nvidia-cuda-nvrtc-cu12==12.1.105 (from torch->transformers[torch])
#   Using cached nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (23.7 MB)
# Collecting nvidia-cuda-runtime-cu12==12.1.105 (from torch->transformers[torch])
#   Using cached nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (823 kB)
# Collecting nvidia-cuda-cupti-cu12==12.1.105 (from torch->transformers[torch])
#   Using cached nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (14.1 MB)
# Collecting nvidia-cudnn-cu12==8.9.2.26 (from torch->transformers[torch])
#   Using cached nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl (731.7 MB)
# Collecting nvidia-cublas-cu12==12.1.3.1 (from torch->transformers[torch])
#   Using cached nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl (410.6 MB)
# Collecting nvidia-cufft-cu12==11.0.2.54 (from torch->transformers[torch])
#   Using cached nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl (121.6 MB)
# Collecting nvidia-curand-cu12==10.3.2.106 (from torch->transformers[torch])
#   Using cached nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl (56.5 MB)
# Collecting nvidia-cusolver-cu12==11.4.5.107 (from torch->transformers[torch])
#   Using cached nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl (124.2 MB)
# Collecting nvidia-cusparse-cu12==12.1.0.106 (from torch->transformers[torch])
#   Using cached nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl (196.0 MB)
# Collecting nvidia-nccl-cu12==2.20.5 (from torch->transformers[torch])
#   Using cached nvidia_nccl_cu12-2.20.5-py3-none-manylinux2014_x86_64.whl (176.2 MB)
# Collecting nvidia-nvtx-cu12==12.1.105 (from torch->transformers[torch])
#   Using cached nvidia_nvtx_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (99 kB)
# Requirement already satisfied: triton==2.3.0 in /usr/local/lib/python3.10/dist-packages (from torch->transformers[torch]) (2.3.0)
# Collecting nvidia-nvjitlink-cu12 (from nvidia-cusolver-cu12==11.4.5.107->torch->transformers[torch])
#   Downloading nvidia_nvjitlink_cu12-12.5.40-py3-none-manylinux2014_x86_64.whl (21.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.3/21.3 MB 37.8 MB/s eta 0:00:00
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->transformers[torch]) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->transformers[torch]) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->transformers[torch]) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->transformers[torch]) (2024.2.2)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch->transformers[torch]) (2.1.5)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch->transformers[torch]) (1.3.0)
# Installing collected packages: nvidia-nvtx-cu12, nvidia-nvjitlink-cu12, nvidia-nccl-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, nvidia-cusparse-cu12, nvidia-cudnn-cu12, nvidia-cusolver-cu12, accelerate
# Successfully installed accelerate-0.30.1 nvidia-cublas-cu12-12.1.3.1 nvidia-cuda-cupti-cu12-12.1.105 nvidia-cuda-nvrtc-cu12-12.1.105 nvidia-cuda-runtime-cu12-12.1.105 nvidia-cudnn-cu12-8.9.2.26 nvidia-cufft-cu12-11.0.2.54 nvidia-curand-cu12-10.3.2.106 nvidia-cusolver-cu12-11.4.5.107 nvidia-cusparse-cu12-12.1.0.106 nvidia-nccl-cu12-2.20.5 nvidia-nvjitlink-cu12-12.5.40 nvidia-nvtx-cu12-12.1.105

# %%
pip install datasets
# Out:
# Collecting datasets
#   Downloading datasets-2.19.1-py3-none-any.whl (542 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 542.0/542.0 kB 9.2 MB/s eta 0:00:00
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from datasets) (3.14.0)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from datasets) (1.25.2)
# Requirement already satisfied: pyarrow>=12.0.0 in /usr/local/lib/python3.10/dist-packages (from datasets) (14.0.2)
# Requirement already satisfied: pyarrow-hotfix in /usr/local/lib/python3.10/dist-packages (from datasets) (0.6)
# Collecting dill<0.3.9,>=0.3.0 (from datasets)
#   Downloading dill-0.3.8-py3-none-any.whl (116 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 10.1 MB/s eta 0:00:00
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from datasets) (2.0.3)
# Requirement already satisfied: requests>=2.19.0 in /usr/local/lib/python3.10/dist-packages (from datasets) (2.31.0)
# Requirement already satisfied: tqdm>=4.62.1 in /usr/local/lib/python3.10/dist-packages (from datasets) (4.66.4)
# Collecting xxhash (from datasets)
#   Downloading xxhash-3.4.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (194 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.1/194.1 kB 12.0 MB/s eta 0:00:00
# Collecting multiprocess (from datasets)
#   Downloading multiprocess-0.70.16-py310-none-any.whl (134 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 11.1 MB/s eta 0:00:00
# Requirement already satisfied: fsspec[http]<=2024.3.1,>=2023.1.0 in /usr/local/lib/python3.10/dist-packages (from datasets) (2023.6.0)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.10/dist-packages (from datasets) (3.9.5)
# Requirement already satisfied: huggingface-hub>=0.21.2 in /usr/local/lib/python3.10/dist-packages (from datasets) (0.23.1)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from datasets) (24.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from datasets) (6.0.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (23.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.9.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (4.0.3)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.21.2->datasets) (4.11.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->datasets) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->datasets) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->datasets) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->datasets) (2024.2.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets) (2023.4)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets) (2024.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas->datasets) (1.16.0)
# Installing collected packages: xxhash, dill, multiprocess, datasets
# Successfully installed datasets-2.19.1 dill-0.3.8 multiprocess-0.70.16 xxhash-3.4.1

# %%
pip install evaluate
# Out:
# Collecting evaluate
#   Downloading evaluate-0.4.2-py3-none-any.whl (84 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 84.1/84.1 kB 3.3 MB/s eta 0:00:00
# Requirement already satisfied: datasets>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from evaluate) (2.19.1)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from evaluate) (1.25.2)
# Requirement already satisfied: dill in /usr/local/lib/python3.10/dist-packages (from evaluate) (0.3.8)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from evaluate) (2.0.3)
# Requirement already satisfied: requests>=2.19.0 in /usr/local/lib/python3.10/dist-packages (from evaluate) (2.31.0)
# Requirement already satisfied: tqdm>=4.62.1 in /usr/local/lib/python3.10/dist-packages (from evaluate) (4.66.4)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.10/dist-packages (from evaluate) (3.4.1)
# Requirement already satisfied: multiprocess in /usr/local/lib/python3.10/dist-packages (from evaluate) (0.70.16)
# Requirement already satisfied: fsspec[http]>=2021.05.0 in /usr/local/lib/python3.10/dist-packages (from evaluate) (2023.6.0)
# Requirement already satisfied: huggingface-hub>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from evaluate) (0.23.1)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from evaluate) (24.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from datasets>=2.0.0->evaluate) (3.14.0)
# Requirement already satisfied: pyarrow>=12.0.0 in /usr/local/lib/python3.10/dist-packages (from datasets>=2.0.0->evaluate) (14.0.2)
# Requirement already satisfied: pyarrow-hotfix in /usr/local/lib/python3.10/dist-packages (from datasets>=2.0.0->evaluate) (0.6)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.10/dist-packages (from datasets>=2.0.0->evaluate) (3.9.5)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from datasets>=2.0.0->evaluate) (6.0.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.7.0->evaluate) (4.11.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->evaluate) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->evaluate) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->evaluate) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->evaluate) (2024.2.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas->evaluate) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->evaluate) (2023.4)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas->evaluate) (2024.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=2.0.0->evaluate) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=2.0.0->evaluate) (23.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=2.0.0->evaluate) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=2.0.0->evaluate) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=2.0.0->evaluate) (1.9.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=2.0.0->evaluate) (4.0.3)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas->evaluate) (1.16.0)
# Installing collected packages: evaluate
# Successfully installed evaluate-0.4.2

# %%
import pandas as pd
df = pd.read_csv("Q&A.csv")

# %%
from datasets import load_dataset
squad = load_dataset("squad")
#squad = squad.train_test_split(test_size=0.2)
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:89: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# Downloading readme:   0%|          | 0.00/7.62k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/14.5M [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/1.82M [00:00<?, ?B/s]
# Generating train split:   0%|          | 0/87599 [00:00<?, ? examples/s]
# Generating validation split:   0%|          | 0/10570 [00:00<?, ? examples/s]

# %%
squad["train"]
# Out:
# Dataset({
#     features: ['id', 'title', 'context', 'question', 'answers'],
#     num_rows: 87599
# })

# %%
data_dict = squad["train"].to_dict()
# Create a DataFrame from the dictionary
squad = pd.DataFrame.from_dict(data_dict)

# %%
squad["answers"][0]
# Out:
# {'text': ['Saint Bernadette Soubirous'], 'answer_start': [515]}

# %%
len(squad['id'].unique())
# Out:
# 87599

# %%
df
# Out:
#                                                sentence  \
# 0     a healthy queen observed, workers are active, ...
# 1     a healthy queen observed, workers are active, ...
# 2     a healthy queen observed, workers are active, ...
# 3     a healthy queen observed, workers are active, ...
# 4     a healthy queen observed, workers are active, ...
# ...                                                 ...
# 3406  queen not detected, workers disoriented, low d...
# 3407  queen not detected, workers disoriented, low d...
# 3408  queen not detected, workers disoriented, low d...
# 3409  queen not detected, workers disoriented, low d...
# 3410  queen not detected, workers disoriented, low d...
#
#                                                question  \
# 0       is there a queen currently present in the hive?
# 1     are there any worker bees currently active in ...
# 2     describe the queen's activity or presence note...
# 3         what types of forage bees have been foraging?
# 4     what types of bee products have been collected...
# ...                                                 ...
# 3406  can you list the bee products available from t...
# 3407  how many honey frames are currently filled in ...
# 3408  can you estimate how many frames are ready for...
# 3409     what is the current health status of the hive?
# 3410         what is the status of workers in the hive?
#
#                                 answer  context_index
# 0                        healthy queen              0
# 1                   workers are active              0
# 2                        healthy queen              0
# 3                     pollen collected              0
# 4                  honey frames filled              0
# ...                                ...            ...
# 3406                      honey frames            270
# 3407  three honey frames underutilized            270
# 3408  three honey frames underutilized            270
# 3409                queen not detected            270
# 3410               workers disoriented            270
#
# [3411 rows x 4 columns]

# %%
squad.head()
# Out:
#                          id                     title  \
# 0  5733be284776f41900661182  University_of_Notre_Dame
# 1  5733be284776f4190066117f  University_of_Notre_Dame
# 2  5733be284776f41900661180  University_of_Notre_Dame
# 3  5733be284776f41900661181  University_of_Notre_Dame
# 4  5733be284776f4190066117e  University_of_Notre_Dame
#
#                                              context  \
# 0  Architecturally, the school has a Catholic cha...
# 1  Architecturally, the school has a Catholic cha...
# 2  Architecturally, the school has a Catholic cha...
# 3  Architecturally, the school has a Catholic cha...
# 4  Architecturally, the school has a Catholic cha...
#
#                                             question  \
# 0  To whom did the Virgin Mary allegedly appear i...
# 1  What is in front of the Notre Dame Main Building?
# 2  The Basilica of the Sacred heart at Notre Dame...
# 3                  What is the Grotto at Notre Dame?
# 4  What sits on top of the Main Building at Notre...
#
#                                              answers
# 0  {'text': ['Saint Bernadette Soubirous'], 'answ...
# 1  {'text': ['a copper statue of Christ'], 'answe...
# 2  {'text': ['the Main Building'], 'answer_start'...
# 3  {'text': ['a Marian place of prayer and reflec...
# 4  {'text': ['a golden statue of the Virgin Mary'...

# %%
df_copy = df

# %%
len(df_copy['sentence'].unique())
# Out:
# 271

# %%
from sklearn.model_selection import train_test_split

train_df, temp_df = train_test_split(df, test_size=0.3, random_state=42, shuffle=True)
valid_df, test_df = train_test_split(temp_df, test_size=0.5, random_state=42, shuffle=True)

# %%
train = df[:1705]
test = df[1705:2561]
validate =df[2561:]

# %%
test
# Out:
#                                                sentence  \
# 1705  queen present, worker bees excelling, drone co...
# 1706  queen present, worker bees excelling, drone co...
# 1707  queen present, worker bees excelling, drone co...
# 1708  queen present, worker bees excelling, drone co...
# 1709  queen present, worker bees excelling, drone co...
# ...                                                 ...
# 2556  queen aging, workers steady, limited drone act...
# 2557  queen aging, workers steady, limited drone act...
# 2558  queen aging, workers steady, limited drone act...
# 2559  queen aging, workers steady, limited drone act...
# 2560  queen aging, workers steady, limited drone act...
#
#                                                question  \
# 1705    is there a queen currently present in the hive?
# 1706  are there any worker bees currently active in ...
# 1707  describe the queen's activity or presence note...
# 1708          what is the status of drones in the hive?
# 1709  what types of bee products have been collected...
# ...                                                 ...
# 2556  can you list the bee products available from t...
# 2557  how many honey frames are currently filled in ...
# 2558  can you estimate how many frames are ready for...
# 2559     what is the current health status of the hive?
# 2560         what is the status of workers in the hive?
#
#                                 answer  context_index
# 1705                     queen present            135
# 1706             worker bees excelling            135
# 1707                     queen present            135
# 1708               drone count optimal            135
# 1709     all frames teeming with honey            135
# ...                                ...            ...
# 2556  eight honey frames nearly filled            202
# 2557  eight honey frames nearly filled            202
# 2558  eight honey frames nearly filled            202
# 2559                       queen aging            202
# 2560                    workers steady            202
#
# [856 rows x 4 columns]

# %%
def transform_data_with_id(df):
    result = []

    grouped = df.groupby('context_index')

    for context_id, group in grouped:
        context = group.iloc[0]['sentence']  # Assuming all sentences in the group are the same
        qas = []
        for _, row in group.iterrows():
            answer_start = context.find(row['answer'])
            qa = {
                'id': f"{len(qas) + 1:05d}",
                'is_impossible': False,
                'question': row['question'],
                'answers': [{
                    'text': row['answer'],
                    'answer_start': answer_start
                }]
            }
            qas.append(qa)

        result.append({
            'context': context,
            'qas': qas
        })

    return result

# %%
train_copy = transform_data_with_id(train_df)
test_copy = transform_data_with_id(test_df)
valid_copy = transform_data_with_id(valid_df)

# %%
train_copy
# Out:
# [{'context': 'a healthy queen observed, workers are active, abundant nectar and pollen collected, with a full count of eggs and six honey frames filled',
#   'qas': [{'id': '00001',
#     'is_impossible': False,
#     'question': 'what is the status of workers in the hive?',
#     'answers': [{'text': 'workers are active', 'answer_start': 26}]},
#    {'id': '00002',
#     'is_impossible': False,
#     'question': 'can you list the bee products available from the latest harvest?',
#     'answers': [{'text': 'honey frames filled', 'answer_start': 118}]},
#    {'id': '00003',
#     'is_impossible': False,
#     'question': 'what is the egg count of the hive?',
#     'answers': [{'text': 'full count of eggs', 'answer_start': 91}]},
#    {'id': '00004',
#     'is_impossible': False,
#     'question': "describe the queen's activity or presence noted in the recent observations?",
#     'answers': [{'text': 'healthy queen', 'answer_start': 2}]},
#    {'id': '00005',
#     'is_impossible': False,
#     'question': 'how many honey frames are currently filled in the hive?',
#     'answers': [{'text': 'six honey frames filled', 'answer_start': 114}]},
#    {'id': '00006',
#     'is_impossible': False,
#     'question': 'what types of forage bees have been foraging?',
#     'answers': [{'text': 'pollen collected', 'answer_start': 66}]},
#    {'id': '00007',
#     'is_impossible': False,
#     'question': "what's the egg production like?",
#     'answers': [{'text': 'full count of eggs', 'answer_start': 91}]},
#    {'id': '00008',
#     'is_impossible': False,
#     'question': 'describe the foraging behavior observed in the worker bees lately?',
#     'answers': [{'text': 'pollen collected', 'answer_start': 66}]},
#    {'id': '00009',
#     'is_impossible': False,
#     'question': 'can you estimate how many frames are ready for harvest?',
#     'answers': [{'text': 'six honey frames filled', 'answer_start': 114}]},
#    {'id': '00010',
#     'is_impossible': False,
#     'question': 'what types of bee products have been collected recently?',
#     'answers': [{'text': 'honey frames filled', 'answer_start': 118}]},
#    {'id': '00011',
#     'is_impossible': False,
#     'question': 'are there any worker bees currently active in the hive?',
#     'answers': [{'text': 'workers are active', 'answer_start': 26}]}]},
#  {'context': 'queenright with an extensive brood pattern, workers exhibit high foraging behavior, honey stores are high, and seven honey frames are heavy with product',
#   'qas': [{'id': '00001',
#     'is_impossible': False,
#     'question': 'what types of bee products have been collected recently?',
#     'answers': [{'text': 'honey frames are heavy with product',
#       'answer_start': 117}]},
#    {'id': '00002',
#     'is_impossible': False,
#     'question': 'describe the foraging behavior observed in the worker bees lately?',
#     'answers': [{'text': 'workers exhibit high foraging behavior',
#       'answer_start': 44}]},
#    {'id': '00003',
#     'is_impossible': False,
#     'question': 'what is the egg count of the hive?',
#     'answers': [{'text': 'extensive brood pattern', 'answer_start': 19}]},
#    {'id': '00004',
#     'is_impossible': False,
#     'question': 'are there any worker bees currently active in the hive?',
#     'answers': [{'text': 'workers exhibit high foraging behavior',
#       'answer_start': 44}]},
#    {'id': '00005',
#     'is_impossible': False,
#     'question': 'how many honey frames are currently filled in the hive?',
#     'answers': [{'text': 'seven honey frames are heavy with product',
#       'answer_start': 111}]},
#    {'id': '00006',
#     'is_impossible': False,
#     'question': 'what is the status of workers in the hive?',
#     'answers': [{'text': 'workers exhibit high foraging behavior',
#       'answer_start': 44}]},
#    {'id': '00007',
#     'is_impossible': False,
#     'question': "what's the egg production like?",
#     'answers': [{'text': 'extensive brood pattern', 'answer_start': 19}]},
#    {'id': '00008',
#     'is_impossible': False,
#     'question': "describe the queen's activity or presence noted in the recent observations?",
#     'answers': [{'text': 'queenright', 'answer_start': 0}]},
#    {'id': '00009',
#     'is_impossible': False,
#     'question': 'what is the status of the queen in the hive?',
#     'answers': [{'text': 'queenright', 'answer_start': 0}]}]},
#  {'context': 'queen’s presence confirmed, strong brood development, a significant amount of propolis, bees actively foraging for nectar, and all ten honey frames being filled',
#   'qas': [{'id': '00001',
#     'is_impossible': False,
#     'question': 'what is the status of workers in the hive?',
#     'answers': [{'text': 'bees actively foraging for nectar',
#       'answer_start': 88}]},
#    {'id': '00002',
#     'is_impossible': False,
#     'question': 'describe the foraging behavior observed in the worker bees lately?',
#     'answers': [{'text': 'bees actively foraging for nectar',
#       'answer_start': 88}]},
#    {'id': '00003',
#     'is_impossible': False,
#     'question': 'can you estimate how many frames are ready for harvest?',
#     'answers': [{'text': 'all ten honey frames being filled',
#       'answer_start': 127}]},
#    {'id': '00004',
#     'is_impossible': False,
#     'question': 'is there a queen currently present in the hive?',
#     'answers': [{'text': 'queen’s presence confirmed', 'answer_start': 0}]},
#    {'id': '00005',
#     'is_impossible': False,
#     'question': 'what is the current health status of the hive?',
#     'answers': [{'text': 'queen’s presence confirmed', 'answer_start': 0}]},
#    {'id': '00006',
#     'is_impossible': False,
#     'question': 'how many honey frames are currently filled in the hive?',
#     'answers': [{'text': 'all ten honey frames being filled',
#       'answer_start': 127}]},
#    {'id': '00007',
#     'is_impossible': False,
#     'question': 'can you list the bee products available from the latest harvest?',
#     'answers': [{'text': 'all ten honey frames being filled',
#       'answer_start': 127}]},
#    {'id': '00008',
#     'is_impossible': False,
#     'question': 'what is the status of the queen in the hive?',
#     'answers': [{'text': 'queen’s presence confirmed', 'answer_start': 0}]},
#    {'id': '00009',
#     'is_impossible': False,
#     'question': 'what is the egg count of the hive?',
#     'answers': [{'text': 'strong brood development', 'answer_start': 28}]}]},
#  {'context': 'queen is laying well, the worker population is high, honey and beeswax levels are sufficient, and there is steady nectar collection with seven honey frames completed',
#   'qas': [{'id': '00001',
#     'is_impossible': False,
#     'question': 'describe the foraging behavior observed in the worker bees lately?',
#     'answers': [{'text': 'there is steady nectar collection with seven honey frames completed',
#       'answer_start': 98}]},
#    {'id': '00002',
#     'is_impossible': False,
#     'question': 'what is the status of workers in the hive?',
#     'answers': [{'text': 'beeswax levels are sufficient',
#       'answer_start': 63}]},
#    {'id': '00003',
#     'is_impossible': False,
#     'question': 'what is the status of the queen in the hive?',
#     'answers': [{'text': 'queen is laying well', 'answer_start': 0}]},
#    {'id': '00004',
#     'is_impossible': False,
#     'question': 'is there a queen currently present in the hive?',
#     'answers': [{'text': 'queen is laying well', 'answer_start': 0}]},
#    {'id': '00005',
#     'is_impossible': False,
#     'question': 'what types of bee products have been collected recently?',
#     'answers': [{'text': 'honey frames completed', 'answer_start': 143}]},
#    {'id': '00006',
#     'is_impossible': False,
#     'question': 'how many honey frames are currently filled in the hive?',
#     'answers': [{'text': 'there is steady nectar collection with seven honey frames completed',
#       'answer_start': 98}]}]},
#  {'context': 'queen is healthy, drone population is normal, abundant forage activity noted, a high volume of eggs present, and five honey frames ready for harvest',
#   'qas': [{'id': '00001',
#     'is_impossible': False,
#     'question': 'what types of forage bees have been foraging?',
#     'answers': [{'text': 'abundant forage activity noted',
#       'answer_start': 46}]},
#    {'id': '00002',
#     'is_impossible': False,
#     'question': 'can you estimate how many frames are ready for harvest?',
#     'answers': [{'text': 'five honey frames ready for harvest',
#       'answer_start': 113}]},
#    {'id': '00003',
#     'is_impossible': False,
#     'question': 'what is the status of the queen in the hive?',
#     'answers': [{'text': 'queen is healthy', 'answer_start': 0}]},
#    {'id': '00004',
#     'is_impossible': False,
#     'question': 'is there a queen currently present in the hive?',
#     'answers': [{'text': 'queen is healthy', 'answer_start': 0}]},
#    {'id': '00005',
#     'is_impossible': False,
#     'question': 'what is the current health status of the hive?',
#     'answers': [{'text': 'queen is healthy', 'answer_start': 0}]},
#    {'id': '00006',
#     'is_impossible': False,
#     'question': "describe the queen's activity or presence noted in the recent observations?",
#     'answers': [{'text': 'queen is healthy', 'answer_start': 0}]},
#    {'id': '00007',
#     'is_impossible': False,
#     'question': 'what is the egg count of the hive?',
#     'answers': [{'text': 'high volume of eggs present', 'answer_start': 80}]},
#    {'id': '00008',
#     'is_impossible': False,
#     'question': 'can you list the bee products available from the latest harvest?',
#     'answers': [{'text': 'honey frames ready', 'answer_start': 118}]},
#    {'id': '00009',
#     'is_impossible': False,
#     'question': 'how many honey frames are currently filled in the hive?',
#     'answers': [{'text': 'five honey frames ready for harvest',
#       'answer_start': 113}]}]},
#  {'context': 'the queen is missing, worker morale seems low, reduced pollen intake, minimal egg laying, and only two honey frames showing progress',
#   'qas': [{'id': '00001',
#     'is_impossible': False,
#     'question': "what's the egg production like?",
#     'answers': [{'text': 'minimal egg laying', 'answer_start': 70}]},
#    {'id': '00002',
#     'is_impossible': False,
#     'question': 'what types of bee products have been collected recently?',
#     'answers': [{'text': 'only honey frames showing progress',
#       'answer_start': -1}]},
#    {'id': '00003',
#     'is_impossible': False,
#     'question': 'can you estimate how many frames are ready for harvest?',
#     'answers': [{'text': 'only two honey frames showing progress',
#       'answer_start': 94}]},
#    {'id': '00004',
#     'is_impossible': False,
#     'question': 'how many honey frames are currently filled in the hive?',
#     'answers': [{'text': 'only two honey frames showing progress',
#       'answer_start': 94}]},
#    {'id': '00005',
#     'is_impossible': False,
#     'question': 'what is the status of the queen in the hive?',
#     'answers': [{'text': 'the queen is missing', 'answer_start': 0}]},
#    {'id': '00006',
#     'is_impossible': False,
#     'question': 'are there any worker bees currently active in the hive?',
#     'answers': [{'text': 'worker morale seems low', 'answer_start': 22}]},
#    {'id': '00007',
#     'is_impossible': False,
#     'question': 'what is the current health status of the hive?',
#     'answers': [{'text': 'the queen is missing', 'answer_start': 0}]},
#    {'id': '00008',
#     'is_impossible': False,
#     'question': 'can you list the bee products available from the latest harvest?',
#     'answers': [{'text': 'only honey frames showing progress',
#       'answer_start': -1}]}]},
#  {'context': 'queen is vibrant, strong scent of propolis, workers bringing in ample nectar, egg count satisfactory, with all honey frames in active production',
#   'qas': [{'id': '00001',
#     'is_impossible': False,
#     'question': 'what types of forage bees have been foraging?',
#     'answers': [{'text': 'workers bringing in ample nectar',
#       'answer_start': 44}]},
#    {'id': '00002',
#     'is_impossible': False,
#     'question': 'what types of bee products have been collected recently?',
#     'answers': [{'text': 'with all honey frames in active production',
#       'answer_start': 102}]},
#    {'id': '00003',
#     'is_impossible': False,
#     'question': "what's the egg production like?",
#     'answers': [{'text': 'egg count satisfactory', 'answer_start': 78}]},
#    {'id': '00004',
#     'is_impossible': False,
#     'question': "describe the queen's activity or presence noted in the recent observations?",
#     'answers': [{'text': 'queen is vibrant', 'answer_start': 0}]},
#    {'id': '00005',
#     'is_impossible': False,
#     'question': 'how many honey frames are currently filled in the hive?',
#     'answers': [{'text': 'with all honey frames in active production',
#       'answer_start': 102}]},
#    {'id': '00006',
#     'is_impossible': False,
#     'question': 'is there a queen currently present in the hive?',
#     'answers': [{'text': 'queen is vibrant', 'answer_start': 0}]},
#    {'id': '00007',
#     'is_impossible': False,
#     'question': 'what is the status of workers in the hive?',
#     'answers': [{'text': 'workers bringing in ample nectar',
#       'answer_start': 44}]},
#    {'id': '00008',
#     'is_impossible': False,
#     'question': 'can you estimate how many frames are ready for harvest?',
#     'answers': [{'text': 'with all honey frames in active production',
#       'answer_start': 102}]},
#    {'id': '00009',
#     'is_impossible': False,
#     'question': 'are there any worker bees currently active in the hive?',
#     'answers': [{'text': 'workers bringing in ample nectar',
#       'answer_start': 44}]},
#    {'id': '00010',
#     'is_impossible': False,
#     'question': 'describe the foraging behavior observed in the worker bees lately?',
#     'answers': [{'text': 'workers bringing in ample nectar',
#       'answer_start': 44}]},
#    {'id': '00011',
#     'is_impossible': False,
#     'question': 'can you list the bee products available from the latest harvest?',
#     'answers': [{'text': 'with all honey frames in active production',
#       'answer_start': 102}]}]},
#  {'context': 'queen is old but active, workers are steady, good pollen reserves, adequate egg laying observed, and four honey frames fully capped',
#   'qas': [{'id': '00001',
#     'is_impossible': False,
#     'question': "what's the egg production like?",
#     'answers': [{'text': 'adequate egg laying', 'answer_start': 67}]},
#    {'id': '00002',
#     'is_impossible': False,
#     'question': 'what types of bee products have been collected recently?',
#     'answers': [{'text': 'honey frames fully capped', 'answer_start': 106}]},
#    {'id': '00003',
#     'is_impossible': False,
#     'question': 'how many honey frames are currently filled in the hive?',
#     'answers': [{'text': 'four honey frames fully capped',
#       'answer_start': 101}]},
#    {'id': '00004',
#     'is_impossible': False,
#     'question': 'what is the egg count of the hive?',
#     'answers': [{'text': 'adequate egg laying', 'answer_start': 67}]},
#    {'id': '00005',
#     'is_impossible': False,
#     'question': 'what is the current health status of the hive?',
#     'answers': [{'text': 'queen is old but active', 'answer_start': 0}]},
#    {'id': '00006',
#     'is_impossible': False,
#     'question': "describe the queen's activity or presence noted in the recent observations?",
#     'answers': [{'text': 'queen is old but active', 'answer_start': 0}]},
#    {'id': '00007',
#     'is_impossible': False,
#     'question': 'can you estimate how many frames are ready for harvest?',
#     'answers': [{'text': 'four honey frames fully capped',
#       'answer_start': 101}]},
#    {'id': '00008',
#     'is_impossible': False,
#     'question': 'what types of forage bees have been foraging?',
#     'answers': [{'text': 'good pollen reserves', 'answer_start': 45}]},
#    {'id': '00009',
#     'is_impossible': False,
#     'question': 'can you list the bee products available from the latest harvest?',
#     'answers': [{'text': 'honey frames fully capped', 'answer_start': 106}]},
#    {'id': '00010',
#     'is_impossible': False,
#     'question': 'is there a queen currently present in the hive?',
#     'answers': [{'text': 'queen is old but active', 'answer_start': 0}]}]},
#  {'context': 'new queen seen, workers are energetic despite the rain, honey stores are fair, and nectar foraging is ongoing with five honey frames filled',
#   'qas': [{'id': '00001',
#     'is_impossible': False,
#     'question': 'what types of bee products have been collected recently?',
#     'answers': [{'text': 'honey frames filled', 'answer_start': 120}]},
#    {'id': '00002',
#     'is_impossible': False,
#     'question': 'can you estimate how many frames are ready for harvest?',
#     'answers': [{'text': 'nectar foraging is ongoing with five honey frames filled',
#       'answer_start': 83}]},
#    {'id': '00003',
#     'is_impossible': False,
#     'question': 'can you list the bee products available from the latest harvest?',
#     'answers': [{'text': 'honey frames filled', 'answer_start': 120}]},
#    {'id': '00004',
#     'is_impossible': False,
#     'question': 'what types of forage bees have been foraging?',
#     'answers': [{'text': 'nectar foraging is ongoing with five honey frames filled',
#       'answer_start': 83}]},
#    {'id': '00005',
#     'is_impossible': False,
#     'question': 'how many honey frames are currently filled in the hive?',
#     'answers': [{'text': 'nectar foraging is ongoing with five honey frames filled',
#       'answer_start': 83}]},
#    {'id': '00006',
#     'is_impossible': False,
#     'question': 'are there any worker bees currently active in the hive?',
#     'answers': [{'text': 'workers are energetic despite the rain',
#       'answer_start': 16}]},
#    {'id': '00007',
#     'is_impossible': False,
#     'question': 'what is the status of the queen in the hive?',
#     'answers': [{'text': 'new queen seen', 'answer_start': 0}]},
#    {'id': '00008',
#     'is_impossible': False,
#     'question': 'describe the foraging behavior observed in the worker bees lately?',
#     'answers': [{'text': 'nectar foraging is ongoing with five honey frames filled',
#       'answer_start': 83}]},
#    {'id': '00009',
#     'is_impossible': False,
#     'question': 'what is the current health status of the hive?',
#     'answers': [{'text': 'new queen seen', 'answer_start': 0}]}]},
#  {'context': 'queen’s health is excellent, worker bees are efficiently foraging, high beeswax production, egg laying at peak, with seven honey frames sealed',
#   'qas': [{'id': '00001',
#     'is_impossible': False,
#     'question': "describe the queen's activity or presence noted in the recent observations?",
#     'answers': [{'text': 'queen’s health is excellent', 'answer_start': 0}]},
#    {'id': '00002',
#     'is_impossible': False,
#     'question': 'what is the status of the queen in the hive?',
#     'answers': [{'text': 'queen’s health is excellent', 'answer_start': 0}]},
#    {'id': '00003',
#     'is_impossible': False,
#     'question': 'is there a queen currently present in the hive?',
#     'answers': [{'text': 'queen’s health is excellent', 'answer_start': 0}]},
#    {'id': '00004',
#     'is_impossible': False,
#     'question': 'can you estimate how many frames are ready for harvest?',
#     'answers': [{'text': 'with seven honey frames sealed',
#       'answer_start': 112}]},
#    {'id': '00005',
#     'is_impossible': False,
#     'question': "what's the egg production like?",
#     'answers': [{'text': 'egg laying at peak', 'answer_start': 92}]},
#    {'id': '00006',
#     'is_impossible': False,
#     'question': 'can you list the bee products available from the latest harvest?',
#     'answers': [{'text': 'honey frames', 'answer_start': 123}]},
#    {'id': '00007',
#     'is_impossible': False,
#     'question': 'how many honey frames are currently filled in the hive?',
#     'answers': [{'text': 'with seven honey frames sealed',
#       'answer_start': 112}]},
#    {'id': '00008',
#     'is_impossible': False,
#     'question': 'what types of bee products have been collected recently?',
#     'answers': [{'text': 'honey frames', 'answer_start': 123}]},
#    {'id': '00009',
#     'is_impossible': False,
#     'question': 'what is the current health status of the hive?',
#     'answers': [{'text': 'queen’s health is excellent', 'answer_start': 0}]},
#    {'id': '00010',
#     'is_impossible': False,
#     'question': 'what is the egg count of the hive?',
#     'answers': [{'text': 'egg laying at peak', 'answer_start': 92}]},
#    {'id': '00011',
#     'is_impossible': False,
#     'question': 'are there any worker bees currently active in the hive?',
#     'answers': [{'text': 'high beeswax production', 'answer_start': 67}]},
#    {'id': '00012',
#     'is_impossible': False,
#     'question': 'describe the foraging behavior observed in the worker bees lately?',
#     'answers': [{'text': 'worker bees are efficiently foraging',
#       'answer_start': 29}]}]},
#  {'context': 'an exceptionally healthy queen, with workers displaying an impressive haul of nectar and pollen; the brood chamber is teeming with new eggs, and almost all honey frames are nearing completion',
#   'qas': [{'id': '00001',
#     'is_impossible': False,
#     'question': "what's the egg production like?",
#     'answers': [{'text': 'the brood chamber is teeming with new eggs',
#       'answer_start': 97}]},
#    {'id': '00002',
#     'is_impossible': False,
#     'question': 'what is the status of the queen in the hive?',
#     'answers': [{'text': 'an exceptionally healthy queen',
#       'answer_start': 0}]},
#    {'id': '00003',
#     'is_impossible': False,
#     'question': 'how many honey frames are currently filled in the hive?',
#     'answers': [{'text': 'almost all honey frames are nearing completion',
#       'answer_start': 145}]},
#    {'id': '00004',
#     'is_impossible': False,
#     'question': 'are there any worker bees currently active in the hive?',
#     'answers': [{'text': 'with workers displaying an impressive haul of nectar',
#       'answer_start': 32}]},
#    {'id': '00005',
#     'is_impossible': False,
#     'question': 'what is the status of workers in the hive?',
#     'answers': [{'text': 'with workers displaying an impressive haul of nectar',
#       'answer_start': 32}]},
#    {'id': '00006',
#     'is_impossible': False,
#     'question': 'what is the current health status of the hive?',
#     'answers': [{'text': 'an exceptionally healthy queen',
#       'answer_start': 0}]},
#    {'id': '00007',
#     'is_impossible': False,
#     'question': 'what types of forage bees have been foraging?',
#     'answers': [{'text': 'pollen; the brood chamber is teeming with new eggs',
#       'answer_start': 89}]},
#    {'id': '00008',
#     'is_impossible': False,
#     'question': "describe the queen's activity or presence noted in the recent observations?",
#     'answers': [{'text': 'an exceptionally healthy queen',
#       'answer_start': 0}]},
#    {'id': '00009',
#     'is_impossible': False,
#     'question': 'can you list the bee products available from the latest harvest?',
#     'answers': [{'text': 'almost all honey frames are nearing completion',
#       'answer_start': 145}]},
#    {'id': '00010',
#     'is_impossible': False,
#     'question': 'can you estimate how many frames are ready for harvest?',
#     'answers': [{'text': 'almost all honey frames are nearing completion',
#       'answer_start': 145}]}]},
#  {'context': 'a queen in her prime, workers in a frenzy of productivity, ample stores of propolis and honey, and a brood pattern so perfect it could be featured in a beekeeping manual',
#   'qas': [{'id': '00001',
#     'is_impossible': False,
#     'question': 'are there any worker bees currently active in the hive?',
#     'answers': [{'text': 'workers in a frenzy of productivity',
#       'answer_start': 22}]},
#    {'id': '00002',
#     'is_impossible': False,
#     'question': 'what is the status of the queen in the hive?',
#     'answers': [{'text': 'a queen in her prime', 'answer_start': 0}]},
#    {'id': '00003',
#     'is_impossible': False,
#     'question': "describe the queen's activity or presence noted in the recent observations?",
#     'answers': [{'text': 'a queen in her prime', 'answer_start': 0}]},
#    {'id': '00004',
#     'is_impossible': False,
#     'question': 'what is the status of workers in the hive?',
#     'answers': [{'text': 'workers in a frenzy of productivity',
#       'answer_start': 22}]},
#    {'id': '00005',
#     'is_impossible': False,
#     'question': 'can you list the bee products available from the latest harvest?',
#     'answers': [{'text': 'honey', 'answer_start': 88}]},
#    {'id': '00006',
#     'is_impossible': False,
#     'question': "what's the egg production like?",
#     'answers': [{'text': 'brood pattern so perfect', 'answer_start': 101}]},
#    {'id': '00007',
#     'is_impossible': False,
#     'question': 'what is the egg count of the hive?',
#     'answers': [{'text': 'brood pattern so perfect', 'answer_start': 101}]}]},
#  {'context': 'a newly emerged queen already proving her worth, workers efficiently managing the nectar flow despite the recent dry spell, and honey frames well on their way to being filled to the brim',
#   'qas': [{'id': '00001',
#     'is_impossible': False,
#     'question': 'what types of bee products have been collected recently?',
#     'answers': [{'text': 'honey frames well on their way to being filled to the brim',
#       'answer_start': 128}]},
#    {'id': '00002',
#     'is_impossible': False,
#     'question': 'what is the current health status of the hive?',
#     'answers': [{'text': 'newly emerged queen', 'answer_start': 2}]},
#    {'id': '00003',
#     'is_impossible': False,
#     'question': 'is there a queen currently present in the hive?',
#     'answers': [{'text': 'newly emerged queen', 'answer_start': 2}]},
#    {'id': '00004',
#     'is_impossible': False,
#     'question': 'how many honey frames are currently filled in the hive?',
#     'answers': [{'text': 'honey frames well on their way to being filled to the brim',
#       'answer_start': 128}]},
#    {'id': '00005',
#     'is_impossible': False,
#     'question': 'what is the status of the queen in the hive?',
#     'answers': [{'text': 'newly emerged queen', 'answer_start': 2}]},
#    {'id': '00006',
#     'is_impossible': False,
#     'question': 'can you list the bee products available from the latest harvest?',
#     'answers': [{'text': 'honey frames well on their way to being filled to the brim',
#       'answer_start': 128}]},
#    {'id': '00007',
#     'is_impossible': False,
#     'question': 'are there any worker bees currently active in the hive?',
#     'answers': [{'text': 'workers efficient', 'answer_start': 49}]},
#    {'id': '00008',
#     'is_impossible': False,
#     'question': "describe the queen's activity or presence noted in the recent observations?",
#     'answers': [{'text': 'newly emerged queen', 'answer_start': 2}]}]},
#  {'context': 'queen present, strong brood, ample pollen and nectar, ten frames of honey',
#   'qas': [{'id': '00001',
#     'is_impossible': False,
#     'question': 'what is the current health status of the hive?',
#     'answers': [{'text': 'queen present', 'answer_start': 0}]},
#    {'id': '00002',
#     'is_impossible': False,
#     'question': 'is there a queen currently present in the hive?',
#     'answers': [{'text': 'queen present', 'answer_start': 0}]},
#    {'id': '00003',
#     'is_impossible': False,
#     'question': 'can you estimate how many frames are ready for harvest?',
#     'answers': [{'text': 'ten frames of honey', 'answer_start': 54}]},
#    {'id': '00004',
#     'is_impossible': False,
#     'question': "describe the queen's activity or presence noted in the recent observations?",
#     'answers': [{'text': 'queen present', 'answer_start': 0}]},
#    {'id': '00005',
#     'is_impossible': False,
#     'question': 'how many honey frames are currently filled in the hive?',
#     'answers': [{'text': 'ten frames of honey', 'answer_start': 54}]}]},
#  {'context': 'weak queen, sparse brood, low forage yield, three honey frames',
#   'qas': [{'id': '00001',
#     'is_impossible': False,
#     'question': 'what types of forage bees have been foraging?',
#     'answers': [{'text': 'low forage yield', 'answer_start': 26}]},
#    {'id': '00002',
#     'is_impossible': False,
#     'question': 'describe the foraging behavior observed in the worker bees lately?',
#     'answers': [{'text': 'low forage yield', 'answer_start': 26}]},
#    {'id': '00003',
#     'is_impossible': False,
#     'question': 'can you estimate how many frames are ready for harvest?',
#     'answers': [{'text': 'three honey frames', 'answer_start': 44}]},
#    {'id': '00004',
#     'is_impossible': False,
#     'question': 'can you list the bee products available from the latest harvest?',
#     'answers': [{'text': 'honey frames', 'answer_start': 50}]},
#    {'id': '00005',
#     'is_impossible': False,
#     'question': 'what types of bee products have been collected recently?',
#     'answers': [{'text': 'honey frames', 'answer_start': 50}]},
#    {'id': '00006',
#     'is_impossible': False,
#     'question': 'what is the status of the queen in the hive?',
#     'answers': [{'text': 'weak queen', 'answer_start': 0}]}]},
#  {'context': 'queen laying well, high worker activity, rich pollen, eight honey frames capped',
#   'qas': [{'id': '00001',
#     'is_impossible': False,
#     'question': 'what is the current health status of the hive?',
#     'answers': [{'text': 'queen laying well', 'answer_start': 0}]},
#    {'id': '00002',
#     'is_impossible': False,
#     'question': 'what types of forage bees have been foraging?',
#     'answers': [{'text': 'rich pollen', 'answer_start': 41}]},
#    {'id': '00003',
#     'is_impossible': False,
#     'question': 'can you estimate how many frames are ready for harvest?',
#     'answers': [{'text': 'eight honey frames capped', 'answer_start': 54}]},
#    {'id': '00004',
#     'is_impossible': False,
#     'question': "describe the queen's activity or presence noted in the recent observations?",
#     'answers': [{'text': 'queen laying well', 'answer_start': 0}]},
#    {'id': '00005',
#     'is_impossible': False,
#     'question': 'describe the foraging behavior observed in the worker bees lately?',
#     'answers': [{'text': 'rich pollen', 'answer_start': 41}]},
#    {'id': '00006',
#     'is_impossible': False,
#     'question': 'what is the status of workers in the hive?',
#     'answers': [{'text': 'high worker activity', 'answer_start': 19}]},
#    {'id': '00007',
#     'is_impossible': False,
#     'question': 'what is the status of the queen in the hive?',
#     'answers': [{'text': 'queen laying well', 'answer_start': 0}]},
#    {'id': '00008',
#     'is_impossible': False,
#     'question': 'can you list the bee products available from the latest harvest?',
#     'answers': [{'text': 'eight honey frames capped', 'answer_start': 54}]}]},
#  {'context': 'no queen seen, brood declining, forage poor, two honey frames half-filled',
#   'qas': [{'id': '00001',
#     'is_impossible': False,
#     'question': 'what is the egg count of the hive?',
#     'answers': [{'text': 'brood declining', 'answer_start': 15}]},
#    {'id': '00002',
#     'is_impossible': False,
#     'question': 'what is the status of the queen in the hive?',
#     'answers': [{'text': 'no queen seen', 'answer_start': 0}]},
#    {'id': '00003',
#     'is_impossible': False,
#     'question': 'is there a queen currently present in the hive?',
#     'answers': [{'text': 'no queen seen', 'answer_start': 0}]},
#    {'id': '00004',
#     'is_impossible': False,
#     'question': 'what types of forage bees have been foraging?',
#     'answers': [{'text': 'forage poor', 'answer_start': 32}]},
#    {'id': '00005',
#     'is_impossible': False,
#     'question': 'can you estimate how many frames are ready for harvest?',
#     'answers': [{'text': 'two honey frames half-filled', 'answer_start': 45}]},
#    {'id': '00006',
#     'is_impossible': False,
#     'question': 'describe the foraging behavior observed in the worker bees lately?',
#     'answers': [{'text': 'forage poor', 'answer_start': 32}]},
#    {'id': '00007',
#     'is_impossible': False,
#     'question': 'how many honey frames are currently filled in the hive?',
#     'answers': [{'text': 'two honey frames half-filled',
#       'answer_start': 45}]}]},
#  {'context': 'strong queen, robust brood, excellent pollen and nectar, nine full honey frames',
#   'qas': [{'id': '00001',
#     'is_impossible': False,
#     'question': 'what is the current health status of the hive?',
#     'answers': [{'text': 'strong queen', 'answer_start': 0}]},
#    {'id': '00002',
#     'is_impossible': False,
#     'question': 'what types of bee products have been collected recently?',
#     'answers': [{'text': 'nine full honey frames', 'answer_start': 57}]},
#    {'id': '00003',
#     'is_impossible': False,
#     'question': 'what is the egg count of the hive?',
#     'answers': [{'text': 'robust brood', 'answer_start': 14}]},
#    {'id': '00004',
#     'is_impossible': False,
#     'question': 'how many honey frames are currently filled in the hive?',
#     'answers': [{'text': 'nine full honey frames', 'answer_start': 57}]},
#    {'id': '00005',
#     'is_impossible': False,
#     'question': "what's the egg production like?",
#     'answers': [{'text': 'robust brood', 'answer_start': 14}]},
#    {'id': '00006',
#     'is_impossible': False,
#     'question': 'what is the status of the queen in the hive?',
#     'answers': [{'text': 'strong queen', 'answer_start': 0}]}]},
#  {'context': 'queen healthy, brood good, forage average, four honey frames ready',
#   'qas': [{'id': '00001',
#     'is_impossible': False,
#     'question': 'what is the status of the queen in the hive?',
#     'answers': [{'text': 'queen healthy', 'answer_start': 0}]},
#    {'id': '00002',
#     'is_impossible': False,
#     'question': 'what is the egg count of the hive?',
#     'answers': [{'text': 'brood good', 'answer_start': 15}]},
#    {'id': '00003',
#     'is_impossible': False,
#     'question': 'what is the current health status of the hive?',
#     'answers': [{'text': 'queen healthy', 'answer_start': 0}]},
#    {'id': '00004',
#     'is_impossible': False,
#     'question': "describe the queen's activity or presence noted in the recent observations?",
#     'answers': [{'text': 'queen healthy', 'answer_start': 0}]},
#    {'id': '00005',
#     'is_impossible': False,
#     'question': "what's the egg production like?",
#     'answers': [{'text': 'brood good', 'answer_start': 15}]},
#    {'id': '00006',
#     'is_impossible': False,
#     'question': 'what types of bee products have been collected recently?',
#     'answers': [{'text': 'honey frames ready', 'answer_start': 48}]},
#    {'id': '00007',
#     'is_impossible': False,
#     'question': 'can you estimate how many frames are ready for harvest?',
#     'answers': [{'text': 'four honey frames ready', 'answer_start': 43}]}]},
#  {'context': 'queen absent, replacing, workers active, six honey frames being filled',
#   'qas': [{'id': '00001',
#     'is_impossible': False,
#     'question': 'what is the status of workers in the hive?',
#     'answers': [{'text': 'workers active', 'answer_start': 25}]},
#    {'id': '00002',
#     'is_impossible': False,
#     'question': 'is there a queen currently present in the hive?',
#     'answers': [{'text': 'queen absent', 'answer_start': 0}]},
#    {'id': '00003',
#     'is_impossible': False,
#     'question': 'are there any worker bees currently active in the hive?',
#     'answers': [{'text': 'workers active', 'answer_start': 25}]},
#    {'id': '00004',
#     'is_impossible': False,
#     'question': 'can you estimate how many frames are ready for harvest?',
#     'answers': [{'text': 'six honey frames being filled',
#       'answer_start': 41}]},
#    {'id': '00005',
#     'is_impossible': False,
#     'question': 'can you list the bee products available from the latest harvest?',
#     'answers': [{'text': 'honey frames being filled', 'answer_start': 45}]},
#    {'id': '00006',
#     'is_impossible': False,
#     'question': 'how many honey frames are currently filled in the hive?',
#     'answers': [{'text': 'six honey frames being filled',
#       'answer_start': 41}]},
#    {'id': '00007',
#     'is_impossible': False,
#     'question': "describe the queen's activity or presence noted in the recent observations?",
#     'answers': [{'text': 'queen absent', 'answer_start': 0}]}]},
#  {'context': 'queen spotted, brood expanding, good pollen collection, seven honey frames sealed',
#   'qas': [{'id': '00001',
#     'is_impossible': False,
#     'question': 'describe the foraging behavior observed in the worker bees lately?',
#     'answers': [{'text': 'good pollen collection', 'answer_start': 32}]},
#    {'id': '00002',
#     'is_impossible': False,
#     'question': 'what is the egg count of the hive?',
#     'answers': [{'text': 'brood exp', 'answer_start': 15}]},
#    {'id': '00003',
#     'is_impossible': False,
#     'question': 'can you list the bee products available from the latest harvest?',
#     'answers': [{'text': 'honey frames', 'answer_start': 62}]},
#    {'id': '00004',
#     'is_impossible': False,
#     'question': 'what types of forage bees have been foraging?',
#     'answers': [{'text': 'good pollen collection', 'answer_start': 32}]},
#    {'id': '00005',
#     'is_impossible': False,
#     'question': 'what is the current health status of the hive?',
#     'answers': [{'text': 'queen spotted', 'answer_start': 0}]},
#    {'id': '00006',
#     'is_impossible': False,
#     'question': 'is there a queen currently present in the hive?',
#     'answers': [{'text': 'queen spotted', 'answer_start': 0}]},
#    {'id': '00007',
#     'is_impossible': False,
#     'question': 'how many honey frames are currently filled in the hive?',
#     'answers': [{'text': 'seven honey frames sealed', 'answer_start': 56}]}]},
#  {'context': 'queen vibrant, full brood chamber, high forage activity, ten honey frames heavy',
#   'qas': [{'id': '00001',
#     'is_impossible': False,
#     'question': 'can you estimate how many frames are ready for harvest?',
#     'answers': [{'text': 'ten honey frames heavy', 'answer_start': 57}]},
#    {'id': '00002',
#     'is_impossible': False,
#     'question': "what's the egg production like?",
#     'answers': [{'text': 'full brood chamber', 'answer_start': 15}]},
#    {'id': '00003',
#     'is_impossible': False,
#     'question': 'describe the foraging behavior observed in the worker bees lately?',
#     'answers': [{'text': 'high forage activity', 'answer_start': 35}]},
#    {'id': '00004',
#     'is_impossible': False,
#     'question': 'is there a queen currently present in the hive?',
#     'answers': [{'text': 'queen vibrant', 'answer_start': 0}]},
#    {'id': '00005',
#     'is_impossible': False,
#     'question': 'what is the status of the queen in the hive?',
#     'answers': [{'text': 'queen vibrant', 'answer_start': 0}]},
#    {'id': '00006',
#     'is_impossible': False,
#     'question': 'what types of forage bees have been foraging?',
#     'answers': [{'text': 'high forage activity', 'answer_start': 35}]},
#    {'id': '00007',
#     'is_impossible': False,
#     'question': 'what types of bee products have been collected recently?',
#     'answers': [{'text': 'ten honey frames heavy', 'answer_start': 57}]}]},
#  {'context': 'old queen, brood steady, moderate foraging, five honey frames completed',
#   'qas': [{'id': '00001',
#     'is_impossible': False,
#     'question': "what's the egg production like?",
#     'answers': [{'text': 'brood steady', 'answer_start': 11}]},
#    {'id': '00002',
#     'is_impossible': False,
#     'question': 'how many honey frames are currently filled in the hive?',
#     'answers': [{'text': 'five honey frames completed', 'answer_start': 44}]},
#    {'id': '00003',
#     'is_impossible': False,
#     'question': 'can you estimate how many frames are ready for harvest?',
#     'answers': [{'text': 'five honey frames completed', 'answer_start': 44}]},
#    {'id': '00004',
#     'is_impossible': False,
#     'question': 'is there a queen currently present in the hive?',
#     'answers': [{'text': 'old queen', 'answer_start': 0}]},
#    {'id': '00005',
#     'is_impossible': False,
#     'question': 'describe the foraging behavior observed in the worker bees lately?',
#     'answers': [{'text': 'moderate foraging', 'answer_start': 25}]},
#    {'id': '00006',
#     'is_impossible': False,
#     'question': 'what types of bee products have been collected recently?',
#     'answers': [{'text': 'honey frames completed', 'answer_start': 49}]},
#    {'id': '00007',
#     'is_impossible': False,
#     'question': 'can you list the bee products available from the latest harvest?',
#     'answers': [{'text': 'honey frames completed', 'answer_start': 49}]}]},
#  {'context': 'new queen, workers bustling, abundant forage, six full honey frames',
#   'qas': [{'id': '00001',
#     'is_impossible': False,
#     'question': 'how many honey frames are currently filled in the hive?',
#     'answers': [{'text': 'six full honey frames', 'answer_start': 46}]},
#    {'id': '00002',
#     'is_impossible': False,
#     'question': 'are there any worker bees currently active in the hive?',
#     'answers': [{'text': 'workers bustling', 'answer_start': 11}]},
#    {'id': '00003',
#     'is_impossible': False,
#     'question': 'what is the status of workers in the hive?',
#     'answers': [{'text': 'workers bustling', 'answer_start': 11}]},
#    {'id': '00004',
#     'is_impossible': False,
#     'question': 'what is the status of the queen in the hive?',
#     'answers': [{'text': 'new queen', 'answer_start': 0}]},
#    {'id': '00005',
#     'is_impossible': False,
#     'question': 'what types of forage bees have been foraging?',
#     'answers': [{'text': 'abundant forage', 'answer_start': 29}]},
#    {'id': '00006',
#     'is_impossible': False,
#     'question': 'what types of bee products have been collected recently?',
#     'answers': [{'text': 'full honey frames', 'answer_start': 50}]}]},
#  {'context': 'queen present, brood healthy, foraging successful, seven honey frames capped',
#   'qas': [{'id': '00001',
#     'is_impossible': False,
#     'question': 'what types of forage bees have been foraging?',
#     'answers': [{'text': 'foraging successful', 'answer_start': 30}]},
#    {'id': '00002',
#     'is_impossible': False,
#     'question': 'what is the status of the queen in the hive?',
#     'answers': [{'text': 'queen present', 'answer_start': 0}]},
#    {'id': '00003',
#     'is_impossible': False,
#     'question': 'what types of bee products have been collected recently?',
#     'answers': [{'text': 'honey frames capped', 'answer_start': 57}]},
#    {'id': '00004',
#     'is_impossible': False,
#     'question': 'can you estimate how many frames are ready for harvest?',
#     'answers': [{'text': 'seven honey frames capped', 'answer_start': 51}]},
#    {'id': '00005',
#     'is_impossible': False,
#     'question': 'what is the egg count of the hive?',
#     'answers': [{'text': 'brood healthy', 'answer_start': 15}]},
#    {'id': '00006',
#     'is_impossible': False,
#     'question': 'can you list the bee products available from the latest harvest?',
#     'answers': [{'text': 'honey frames capped', 'answer_start': 57}]},
#    {'id': '00007',
#     'is_impossible': False,
#     'question': "what's the egg production like?",
#     'answers': [{'text': 'brood healthy', 'answer_start': 15}]},
#    {'id': '00008',
#     'is_impossible': False,
#     'question': 'how many honey frames are currently filled in the hive?',
#     'answers': [{'text': 'seven honey frames capped', 'answer_start': 51}]},
#    {'id': '00009',
#     'is_impossible': False,
#     'question': 'what is the current health status of the hive?',
#     'answers': [{'text': 'queen present', 'answer_start': 0}]},
#    {'id': '00010',
#     'is_impossible': False,
#     'question': "describe the queen's activity or presence noted in the recent observations?",
#     'answers': [{'text': 'queen present', 'answer_start': 0}]},
#    {'id': '00011',
#     'is_impossible': False,
#     'question': 'is there a queen currently present in the hive?',
#     'answers': [{'text': 'queen present', 'answer_start': 0}]}]},
#  {'context': 'queen unspotted, brood fair, forage low, four honey frames stored',
#   'qas': [{'id': '00001',
#     'is_impossible': False,
#     'question': 'what types of bee products have been collected recently?',
#     'answers': [{'text': 'honey frames stored', 'answer_start': 46}]},
#    {'id': '00002',
#     'is_impossible': False,
#     'question': 'can you estimate how many frames are ready for harvest?',
#     'answers': [{'text': 'four honey frames stored', 'answer_start': 41}]},
#    {'id': '00003',
#     'is_impossible': False,
#     'question': 'can you list the bee products available from the latest harvest?',
#     'answers': [{'text': 'honey frames stored', 'answer_start': 46}]},
#    {'id': '00004',
#     'is_impossible': False,
#     'question': 'what is the status of the queen in the hive?',
#     'answers': [{'text': 'queen unspotted', 'answer_start': 0}]},
#    {'id': '00005',
#     'is_impossible': False,
#     'question': "what's the egg production like?",
#     'answers': [{'text': 'brood fair', 'answer_start': 17}]}]},
#  {'context': 'active queen, strong brood, good nectar flow, eight honey frames filled',
#   'qas': [{'id': '00001',
#     'is_impossible': False,
#     'question': 'what types of bee products have been collected recently?',
#     'answers': [{'text': 'eight honey frames filled', 'answer_start': 46}]},
#    {'id': '00002',
#     'is_impossible': False,
#     'question': 'how many honey frames are currently filled in the hive?',
#     'answers': [{'text': 'eight honey frames filled', 'answer_start': 46}]},
#    {'id': '00003',
#     'is_impossible': False,
#     'question': "what's the egg production like?",
#     'answers': [{'text': 'strong brood', 'answer_start': 14}]},
#    {'id': '00004',
#     'is_impossible': False,
#     'question': 'what types of forage bees have been foraging?',
#     'answers': [{'text': 'good nectar flow', 'answer_start': 28}]},
#    {'id': '00005',
#     'is_impossible': False,
#     'question': "describe the queen's activity or presence noted in the recent observations?",
#     'answers': [{'text': 'active queen', 'answer_start': 0}]},
#    {'id': '00006',
#     'is_impossible': False,
#     'question': 'describe the foraging behavior observed in the worker bees lately?',
#     'answers': [{'text': 'good nectar flow', 'answer_start': 28}]},
#    {'id': '00007',
#     'is_impossible': False,
#     'question': 'what is the current health status of the hive?',
#     'answers': [{'text': 'active queen', 'answer_start': 0}]},
#    {'id': '00008',
#     'is_impossible': False,
#     'question': 'can you estimate how many frames are ready for harvest?',
#     'answers': [{'text': 'eight honey frames filled', 'answer_start': 46}]},
#    {'id': '00009',
#     'is_impossible': False,
#     'question': 'what is the egg count of the hive?',
#     'answers': [{'text': 'strong brood', 'answer_start': 14}]}]},
#  {'context': 'queen productive, brood plentiful, forage high, nine honey frames ready',
#   'qas': [{'id': '00001',
#     'is_impossible': False,
#     'question': 'what types of bee products have been collected recently?',
#     'answers': [{'text': 'nine honey frames ready', 'answer_start': 48}]},
#    {'id': '00002',
#     'is_impossible': False,
#     'question': 'can you estimate how many frames are ready for harvest?',
#     'answers': [{'text': 'nine honey frames ready', 'answer_start': 48}]},
#    {'id': '00003',
#     'is_impossible': False,
#     'question': 'what is the egg count of the hive?',
#     'answers': [{'text': 'brood plentiful', 'answer_start': 18}]},
#    {'id': '00004',
#     'is_impossible': False,
#     'question': 'can you list the bee products available from the latest harvest?',
#     'answers': [{'text': 'nine honey frames ready', 'answer_start': 48}]},
#    {'id': '00005',
#     'is_impossible': False,
#     'question': 'what is the current health status of the hive?',
#     'answers': [{'text': 'queen productive', 'answer_start': 0}]},
#    {'id': '00006',
#     'is_impossible': False,
#     'question': 'what types of forage bees have been foraging?',
#     'answers': [{'text': 'forage high', 'answer_start': 35}]},
#    {'id': '00007',
#     'is_impossible': False,
#     'question': "describe the queen's activity or presence noted in the recent observations?",
#     'answers': [{'text': 'queen productive', 'answer_start': 0}]},
#    {'id': '00008',
#     'is_impossible': False,
#     'question': "what's the egg production like?",
#     'answers': [{'text': 'brood plentiful', 'answer_start': 18}]},
#    {'id': '00009',
#     'is_impossible': False,
#     'question': 'describe the foraging behavior observed in the worker bees lately?',
#     'answers': [{'text': 'forage high', 'answer_start': 35}]},
#    {'id': '00010',
#     'is_impossible': False,
# ...
#     'is_impossible': False,
#     'question': 'what is the status of the queen in the hive?',
#     'answers': [{'text': 'queen absent', 'answer_start': 0}]},
#    {'id': '00005',
#     'is_impossible': False,
#     'question': 'what is the status of workers in the hive?',
#     'answers': [{'text': 'unmotivated workers', 'answer_start': 14}]}]},
#  {'context': 'queen aging, steady workers, reduced drones, moderate eggs, with eight frames filled with honey',
#   'qas': [{'id': '00001',
#     'is_impossible': False,
#     'question': "what's the egg production like?",
#     'answers': [{'text': 'moderate eggs', 'answer_start': 45}]},
#    {'id': '00002',
#     'is_impossible': False,
#     'question': 'what types of bee products have been collected recently?',
#     'answers': [{'text': 'with eight frames filled with honey',
#       'answer_start': 60}]},
#    {'id': '00003',
#     'is_impossible': False,
#     'question': 'what is the status of drones in the hive?',
#     'answers': [{'text': 'reduced drones', 'answer_start': 29}]},
#    {'id': '00004',
#     'is_impossible': False,
#     'question': 'how many honey frames are currently filled in the hive?',
#     'answers': [{'text': 'with eight frames filled with honey',
#       'answer_start': 60}]},
#    {'id': '00005',
#     'is_impossible': False,
#     'question': 'what is the current health status of the hive?',
#     'answers': [{'text': 'queen aging', 'answer_start': 0}]},
#    {'id': '00006',
#     'is_impossible': False,
#     'question': 'what is the egg count of the hive?',
#     'answers': [{'text': 'moderate eggs', 'answer_start': 45}]},
#    {'id': '00007',
#     'is_impossible': False,
#     'question': 'what is the status of workers in the hive?',
#     'answers': [{'text': 'steady workers', 'answer_start': 13}]},
#    {'id': '00008',
#     'is_impossible': False,
#     'question': 'can you list the bee products available from the latest harvest?',
#     'answers': [{'text': 'with eight frames filled with honey',
#       'answer_start': 60}]}]},
#  {'context': 'queen not found, minimal worker activity, down drone count, slow egg production, and six frames needing attention',
#   'qas': [{'id': '00001',
#     'is_impossible': False,
#     'question': 'are there any worker bees currently active in the hive?',
#     'answers': [{'text': 'minimal worker activity', 'answer_start': 17}]},
#    {'id': '00002',
#     'is_impossible': False,
#     'question': 'what is the status of drones in the hive?',
#     'answers': [{'text': 'down drone count', 'answer_start': 42}]},
#    {'id': '00003',
#     'is_impossible': False,
#     'question': 'what is the status of the queen in the hive?',
#     'answers': [{'text': 'queen not found', 'answer_start': 0}]},
#    {'id': '00004',
#     'is_impossible': False,
#     'question': 'what is the current health status of the hive?',
#     'answers': [{'text': 'queen not found', 'answer_start': 0}]},
#    {'id': '00005',
#     'is_impossible': False,
#     'question': 'is there a queen currently present in the hive?',
#     'answers': [{'text': 'queen not found', 'answer_start': 0}]},
#    {'id': '00006',
#     'is_impossible': False,
#     'question': 'what is the status of workers in the hive?',
#     'answers': [{'text': 'minimal worker activity', 'answer_start': 17}]},
#    {'id': '00007',
#     'is_impossible': False,
#     'question': "what's the egg production like?",
#     'answers': [{'text': 'low egg production', 'answer_start': 61}]},
#    {'id': '00008',
#     'is_impossible': False,
#     'question': 'how many honey frames are currently filled in the hive?',
#     'answers': [{'text': 'six frames needing attention', 'answer_start': 85}]},
#    {'id': '00009',
#     'is_impossible': False,
#     'question': "describe the queen's activity or presence noted in the recent observations?",
#     'answers': [{'text': 'queen not found', 'answer_start': 0}]}]},
#  {'context': 'queen vibrant, numerous worker  bees, adequate drones, eggs filling up, and eleven honey frames topped off',
#   'qas': [{'id': '00001',
#     'is_impossible': False,
#     'question': 'what is the status of drones in the hive?',
#     'answers': [{'text': 'adequate drones', 'answer_start': 38}]},
#    {'id': '00002',
#     'is_impossible': False,
#     'question': 'is there a queen currently present in the hive?',
#     'answers': [{'text': 'queen vibrant', 'answer_start': 0}]},
#    {'id': '00003',
#     'is_impossible': False,
#     'question': 'can you estimate how many frames are ready for harvest?',
#     'answers': [{'text': 'eleven honey frames topped off',
#       'answer_start': 76}]},
#    {'id': '00004',
#     'is_impossible': False,
#     'question': 'how many honey frames are currently filled in the hive?',
#     'answers': [{'text': 'eleven honey frames topped off',
#       'answer_start': 76}]},
#    {'id': '00005',
#     'is_impossible': False,
#     'question': 'what is the current health status of the hive?',
#     'answers': [{'text': 'queen vibrant', 'answer_start': 0}]},
#    {'id': '00006',
#     'is_impossible': False,
#     'question': 'what is the egg count of the hive?',
#     'answers': [{'text': 'eggs filling up', 'answer_start': 55}]},
#    {'id': '00007',
#     'is_impossible': False,
#     'question': "describe the queen's activity or presence noted in the recent observations?",
#     'answers': [{'text': 'queen vibrant', 'answer_start': 0}]}]},
#  {'context': 'queen struggling, workers doing their best, few drones, low egg count, with seven frames partially filled',
#   'qas': [{'id': '00001',
#     'is_impossible': False,
#     'question': 'what is the egg count of the hive?',
#     'answers': [{'text': 'low egg count', 'answer_start': 56}]},
#    {'id': '00002',
#     'is_impossible': False,
#     'question': 'are there any worker bees currently active in the hive?',
#     'answers': [{'text': 'workers doing their best', 'answer_start': 18}]},
#    {'id': '00003',
#     'is_impossible': False,
#     'question': 'can you estimate how many frames are ready for harvest?',
#     'answers': [{'text': 'with seven frames partially filled',
#       'answer_start': 71}]},
#    {'id': '00004',
#     'is_impossible': False,
#     'question': 'what is the current health status of the hive?',
#     'answers': [{'text': 'queen struggling', 'answer_start': 0}]},
#    {'id': '00005',
#     'is_impossible': False,
#     'question': 'is there a queen currently present in the hive?',
#     'answers': [{'text': 'queen struggling', 'answer_start': 0}]},
#    {'id': '00006',
#     'is_impossible': False,
#     'question': 'what is the status of workers in the hive?',
#     'answers': [{'text': 'workers doing their best', 'answer_start': 18}]},
#    {'id': '00007',
#     'is_impossible': False,
#     'question': 'what is the status of the queen in the hive?',
#     'answers': [{'text': 'queen struggling', 'answer_start': 0}]},
#    {'id': '00008',
#     'is_impossible': False,
#     'question': "describe the queen's activity or presence noted in the recent observations?",
#     'answers': [{'text': 'queen struggling', 'answer_start': 0}]},
#    {'id': '00009',
#     'is_impossible': False,
#     'question': 'what is the status of drones in the hive?',
#     'answers': [{'text': 'few drones', 'answer_start': 44}]}]},
#  {'context': 'queen excellent, performing well workers, plentiful drones, well-laid eggs, and all ten honey frames capped and ready',
#   'qas': [{'id': '00001',
#     'is_impossible': False,
#     'question': 'what is the status of drones in the hive?',
#     'answers': [{'text': 'plentiful drones', 'answer_start': 42}]},
#    {'id': '00002',
#     'is_impossible': False,
#     'question': 'what is the egg count of the hive?',
#     'answers': [{'text': 'well-laid eggs', 'answer_start': 60}]},
#    {'id': '00003',
#     'is_impossible': False,
#     'question': 'is there a queen currently present in the hive?',
#     'answers': [{'text': 'queen excellent', 'answer_start': 0}]},
#    {'id': '00004',
#     'is_impossible': False,
#     'question': 'what types of bee products have been collected recently?',
#     'answers': [{'text': 'all ten honey frames capped', 'answer_start': 80}]},
#    {'id': '00005',
#     'is_impossible': False,
#     'question': 'can you estimate how many frames are ready for harvest?',
#     'answers': [{'text': 'all ten honey frames capped', 'answer_start': 80}]},
#    {'id': '00006',
#     'is_impossible': False,
#     'question': 'what is the status of the queen in the hive?',
#     'answers': [{'text': 'queen excellent', 'answer_start': 0}]},
#    {'id': '00007',
#     'is_impossible': False,
#     'question': 'can you list the bee products available from the latest harvest?',
#     'answers': [{'text': 'all ten honey frames capped', 'answer_start': 80}]},
#    {'id': '00008',
#     'is_impossible': False,
#     'question': 'what is the current health status of the hive?',
#     'answers': [{'text': 'queen excellent', 'answer_start': 0}]},
#    {'id': '00009',
#     'is_impossible': False,
#     'question': 'how many honey frames are currently filled in the hive?',
#     'answers': [{'text': 'all ten honey frames capped', 'answer_start': 80}]},
#    {'id': '00010',
#     'is_impossible': False,
#     'question': 'what is the status of workers in the hive?',
#     'answers': [{'text': 'performing well workers', 'answer_start': 17}]},
#    {'id': '00011',
#     'is_impossible': False,
#     'question': 'are there any worker bees currently active in the hive?',
#     'answers': [{'text': 'performing well workers', 'answer_start': 17}]}]},
#  {'context': 'queen missing, lethargic workers, disappearing drones, scarce eggs, and only five frames showing some honey',
#   'qas': [{'id': '00001',
#     'is_impossible': False,
#     'question': 'how many honey frames are currently filled in the hive?',
#     'answers': [{'text': 'only five frames showing some honey',
#       'answer_start': 72}]},
#    {'id': '00002',
#     'is_impossible': False,
#     'question': 'is there a queen currently present in the hive?',
#     'answers': [{'text': 'queen missing', 'answer_start': 0}]},
#    {'id': '00003',
#     'is_impossible': False,
#     'question': "what's the egg production like?",
#     'answers': [{'text': 'scarce eggs', 'answer_start': 55}]},
#    {'id': '00004',
#     'is_impossible': False,
#     'question': 'what is the status of the queen in the hive?',
#     'answers': [{'text': 'queen missing', 'answer_start': 0}]},
#    {'id': '00005',
#     'is_impossible': False,
#     'question': 'what is the status of workers in the hive?',
#     'answers': [{'text': 'lethargic workers', 'answer_start': 15}]},
#    {'id': '00006',
#     'is_impossible': False,
#     'question': 'can you list the bee products available from the latest harvest?',
#     'answers': [{'text': 'frames', 'answer_start': 82}]},
#    {'id': '00007',
#     'is_impossible': False,
#     'question': 'what is the current health status of the hive?',
#     'answers': [{'text': 'queen missing', 'answer_start': 0}]}]},
#  {'context': 'queen healthy, efficient workers, numerous drones, prolific eggs, and ten frames fully stocked with honey',
#   'qas': [{'id': '00001',
#     'is_impossible': False,
#     'question': "describe the queen's activity or presence noted in the recent observations?",
#     'answers': [{'text': 'queen healthy', 'answer_start': 0}]},
#    {'id': '00002',
#     'is_impossible': False,
#     'question': 'what is the status of drones in the hive?',
#     'answers': [{'text': 'numerous drones', 'answer_start': 34}]},
#    {'id': '00003',
#     'is_impossible': False,
#     'question': "what's the egg production like?",
#     'answers': [{'text': 'prolific eggs', 'answer_start': 51}]},
#    {'id': '00004',
#     'is_impossible': False,
#     'question': 'can you estimate how many frames are ready for harvest?',
#     'answers': [{'text': 'ten frames fully stocked with honey',
#       'answer_start': 70}]},
#    {'id': '00005',
#     'is_impossible': False,
#     'question': 'what is the status of the queen in the hive?',
#     'answers': [{'text': 'queen healthy', 'answer_start': 0}]},
#    {'id': '00006',
#     'is_impossible': False,
#     'question': 'what is the egg count of the hive?',
#     'answers': [{'text': 'prolific eggs', 'answer_start': 51}]},
#    {'id': '00007',
#     'is_impossible': False,
#     'question': 'what is the status of workers in the hive?',
#     'answers': [{'text': 'efficient workers', 'answer_start': 15}]},
#    {'id': '00008',
#     'is_impossible': False,
#     'question': 'how many honey frames are currently filled in the hive?',
#     'answers': [{'text': 'ten frames fully stocked with honey',
#       'answer_start': 70}]},
#    {'id': '00009',
#     'is_impossible': False,
#     'question': 'what is the current health status of the hive?',
#     'answers': [{'text': 'queen healthy', 'answer_start': 0}]},
#    {'id': '00010',
#     'is_impossible': False,
#     'question': 'can you list the bee products available from the latest harvest?',
#     'answers': [{'text': 'ten frames fully stocked with honey',
#       'answer_start': 70}]}]},
#  {'context': 'queen absent, disorganized workers, scarce drones, few eggs laid, and seven honey frames poorly stocked',
#   'qas': [{'id': '00001',
#     'is_impossible': False,
#     'question': 'what is the status of the queen in the hive?',
#     'answers': [{'text': 'queen absent', 'answer_start': 0}]},
#    {'id': '00002',
#     'is_impossible': False,
#     'question': 'are there any worker bees currently active in the hive?',
#     'answers': [{'text': 'disorganized workers', 'answer_start': 14}]},
#    {'id': '00003',
#     'is_impossible': False,
#     'question': 'can you list the bee products available from the latest harvest?',
#     'answers': [{'text': 'honey frames', 'answer_start': 76}]},
#    {'id': '00004',
#     'is_impossible': False,
#     'question': 'can you estimate how many frames are ready for harvest?',
#     'answers': [{'text': 'seven honey frames poorly stocked',
#       'answer_start': 70}]},
#    {'id': '00005',
#     'is_impossible': False,
#     'question': 'what is the status of workers in the hive?',
#     'answers': [{'text': 'disorganized workers', 'answer_start': 14}]},
#    {'id': '00006',
#     'is_impossible': False,
#     'question': 'is there a queen currently present in the hive?',
#     'answers': [{'text': 'queen absent', 'answer_start': 0}]},
#    {'id': '00007',
#     'is_impossible': False,
#     'question': 'what types of bee products have been collected recently?',
#     'answers': [{'text': 'honey frames', 'answer_start': 76}]},
#    {'id': '00008',
#     'is_impossible': False,
#     'question': "describe the queen's activity or presence noted in the recent observations?",
#     'answers': [{'text': 'queen absent', 'answer_start': 0}]},
#    {'id': '00009',
#     'is_impossible': False,
#     'question': 'what is the current health status of the hive?',
#     'answers': [{'text': 'queen absent', 'answer_start': 0}]}]},
#  {'context': 'queen not detected, workers disoriented, low drone count, minimal egg laying, and three honey frames underutilized',
#   'qas': [{'id': '00001',
#     'is_impossible': False,
#     'question': 'what is the status of workers in the hive?',
#     'answers': [{'text': 'workers disoriented', 'answer_start': 20}]},
#    {'id': '00002',
#     'is_impossible': False,
#     'question': 'what is the egg count of the hive?',
#     'answers': [{'text': 'minimal egg laying', 'answer_start': 58}]},
#    {'id': '00003',
#     'is_impossible': False,
#     'question': 'are there any worker bees currently active in the hive?',
#     'answers': [{'text': 'workers disoriented', 'answer_start': 20}]},
#    {'id': '00004',
#     'is_impossible': False,
#     'question': 'can you estimate how many frames are ready for harvest?',
#     'answers': [{'text': 'three honey frames underutilized',
#       'answer_start': 82}]},
#    {'id': '00005',
#     'is_impossible': False,
#     'question': 'what types of bee products have been collected recently?',
#     'answers': [{'text': 'honey frames', 'answer_start': 88}]},
#    {'id': '00006',
#     'is_impossible': False,
#     'question': 'how many honey frames are currently filled in the hive?',
#     'answers': [{'text': 'three honey frames underutilized',
#       'answer_start': 82}]},
#    {'id': '00007',
#     'is_impossible': False,
#     'question': 'what is the status of drones in the hive?',
#     'answers': [{'text': 'low drone count', 'answer_start': 41}]}]}]

# %%
flat_data = []
for entry in train_copy:
    context = entry['context']
    for qa in entry['qas']:
        flat_entry = {
            'context': context,
            'id': qa['id'],
            'is_impossible': qa['is_impossible'],
            'question': qa['question'],
            'answers':   qa['answers']
        }
        flat_data.append(flat_entry)

train_transformed = pd.DataFrame(flat_data)

# %%
train_transformed
# Out:
#                                                 context     id  is_impossible  \
# 0     a healthy queen observed, workers are active, ...  00001          False
# 1     a healthy queen observed, workers are active, ...  00002          False
# 2     a healthy queen observed, workers are active, ...  00003          False
# 3     a healthy queen observed, workers are active, ...  00004          False
# 4     a healthy queen observed, workers are active, ...  00005          False
# ...                                                 ...    ...            ...
# 2382  queen not detected, workers disoriented, low d...  00003          False
# 2383  queen not detected, workers disoriented, low d...  00004          False
# 2384  queen not detected, workers disoriented, low d...  00005          False
# 2385  queen not detected, workers disoriented, low d...  00006          False
# 2386  queen not detected, workers disoriented, low d...  00007          False
#
#                                                question  \
# 0            what is the status of workers in the hive?
# 1     can you list the bee products available from t...
# 2                    what is the egg count of the hive?
# 3     describe the queen's activity or presence note...
# 4     how many honey frames are currently filled in ...
# ...                                                 ...
# 2382  are there any worker bees currently active in ...
# 2383  can you estimate how many frames are ready for...
# 2384  what types of bee products have been collected...
# 2385  how many honey frames are currently filled in ...
# 2386          what is the status of drones in the hive?
#
#                                                 answers
# 0     [{'text': 'workers are active', 'answer_start'...
# 1     [{'text': 'honey frames filled', 'answer_start...
# 2     [{'text': 'full count of eggs', 'answer_start'...
# 3        [{'text': 'healthy queen', 'answer_start': 2}]
# 4     [{'text': 'six honey frames filled', 'answer_s...
# ...                                                 ...
# 2382  [{'text': 'workers disoriented', 'answer_start...
# 2383  [{'text': 'three honey frames underutilized', ...
# 2384     [{'text': 'honey frames', 'answer_start': 88}]
# 2385  [{'text': 'three honey frames underutilized', ...
# 2386  [{'text': 'low drone count', 'answer_start': 41}]
#
# [2387 rows x 5 columns]

# %%
flat_data = []
for entry in valid_copy:
    context = entry['context']
    for qa in entry['qas']:
        flat_entry = {
            'context': context,
            'id': qa['id'],
            'is_impossible': qa['is_impossible'],
            'question': qa['question'],
            'answers':   qa['answers']
        }
        flat_data.append(flat_entry)

valid_transformed = pd.DataFrame(flat_data)

# %%
valid_transformed
# Out:
#                                                context     id  is_impossible  \
# 0    a healthy queen observed, workers are active, ...  00001          False
# 1    a healthy queen observed, workers are active, ...  00002          False
# 2    a healthy queen observed, workers are active, ...  00003          False
# 3    queenright with an extensive brood pattern, wo...  00001          False
# 4    queenright with an extensive brood pattern, wo...  00002          False
# ..                                                 ...    ...            ...
# 507  queen absent, disorganized workers, scarce dro...  00001          False
# 508  queen not detected, workers disoriented, low d...  00001          False
# 509  queen not detected, workers disoriented, low d...  00002          False
# 510  queen not detected, workers disoriented, low d...  00003          False
# 511  queen not detected, workers disoriented, low d...  00004          False
#
#                                               question  \
# 0      is there a queen currently present in the hive?
# 1       what is the current health status of the hive?
# 2         what is the status of the queen in the hive?
# 3       what is the current health status of the hive?
# 4    can you estimate how many frames are ready for...
# ..                                                 ...
# 507                 what is the egg count of the hive?
# 508       what is the status of the queen in the hive?
# 509  describe the queen's activity or presence note...
# 510     what is the current health status of the hive?
# 511                    what's the egg production like?
#
#                                                answers
# 0       [{'text': 'healthy queen', 'answer_start': 2}]
# 1       [{'text': 'healthy queen', 'answer_start': 2}]
# 2       [{'text': 'healthy queen', 'answer_start': 2}]
# 3          [{'text': 'queenright', 'answer_start': 0}]
# 4    [{'text': 'seven honey frames are heavy with p...
# ..                                                 ...
# 507         [{'text': 'few eggs', 'answer_start': 51}]
# 508  [{'text': 'queen not detected', 'answer_start'...
# 509  [{'text': 'queen not detected', 'answer_start'...
# 510  [{'text': 'queen not detected', 'answer_start'...
# 511  [{'text': 'minimal egg laying', 'answer_start'...
#
# [512 rows x 5 columns]

# %%
flat_data = []
for entry in test_copy:
    context = entry['context']
    for qa in entry['qas']:
        flat_entry = {
            'context': context,
            'id': qa['id'],
            'is_impossible': qa['is_impossible'],
            'question': qa['question'],
            'answers':   qa['answers']
        }
        flat_data.append(flat_entry)

test_transformed = pd.DataFrame(flat_data)

# %%
test_transformed
# Out:
#                                                context     id  is_impossible  \
# 0    queenright with an extensive brood pattern, wo...  00001          False
# 1    queenright with an extensive brood pattern, wo...  00002          False
# 2    queenright with an extensive brood pattern, wo...  00003          False
# 3    queen’s presence confirmed, strong brood devel...  00001          False
# 4    queen is laying well, the worker population is...  00001          False
# ..                                                 ...    ...            ...
# 507  queen absent, disorganized workers, scarce dro...  00001          False
# 508  queen absent, disorganized workers, scarce dro...  00002          False
# 509  queen absent, disorganized workers, scarce dro...  00003          False
# 510  queen not detected, workers disoriented, low d...  00001          False
# 511  queen not detected, workers disoriented, low d...  00002          False
#
#                                               question  \
# 0        what types of forage bees have been foraging?
# 1      is there a queen currently present in the hive?
# 2    can you list the bee products available from t...
# 3    what types of bee products have been collected...
# 4    are there any worker bees currently active in ...
# ..                                                 ...
# 507                    what's the egg production like?
# 508          what is the status of drones in the hive?
# 509  how many honey frames are currently filled in ...
# 510    is there a queen currently present in the hive?
# 511  can you list the bee products available from t...
#
#                                                answers
# 0    [{'text': 'workers exhibit high foraging behav...
# 1          [{'text': 'queenright', 'answer_start': 0}]
# 2    [{'text': 'honey frames are heavy with product...
# 3    [{'text': 'all ten honey frames being filled',...
# 4    [{'text': 'beeswax levels are sufficient', 'an...
# ..                                                 ...
# 507         [{'text': 'few eggs', 'answer_start': 51}]
# 508    [{'text': 'scarce drones', 'answer_start': 36}]
# 509  [{'text': 'seven honey frames poorly stocked',...
# 510  [{'text': 'queen not detected', 'answer_start'...
# 511     [{'text': 'honey frames', 'answer_start': 88}]
#
# [512 rows x 5 columns]

# %%
def transform_answers(answer_list):
    return {
        'text': [ans['text'] for ans in answer_list],
        'answer_start': [ans['answer_start'] for ans in answer_list]
    }

# %%
train_transformed['answers'] = train_transformed['answers'].apply(transform_answers)
valid_transformed['answers'] = valid_transformed['answers'].apply(transform_answers)
test_transformed['answers'] = test_transformed['answers'].apply(transform_answers)

# %%
test_transformed
# Out:
#                                                context     id  is_impossible  \
# 0    queenright with an extensive brood pattern, wo...  00001          False
# 1    queenright with an extensive brood pattern, wo...  00002          False
# 2    queenright with an extensive brood pattern, wo...  00003          False
# 3    queen’s presence confirmed, strong brood devel...  00001          False
# 4    queen is laying well, the worker population is...  00001          False
# ..                                                 ...    ...            ...
# 507  queen absent, disorganized workers, scarce dro...  00001          False
# 508  queen absent, disorganized workers, scarce dro...  00002          False
# 509  queen absent, disorganized workers, scarce dro...  00003          False
# 510  queen not detected, workers disoriented, low d...  00001          False
# 511  queen not detected, workers disoriented, low d...  00002          False
#
#                                               question  \
# 0        what types of forage bees have been foraging?
# 1      is there a queen currently present in the hive?
# 2    can you list the bee products available from t...
# 3    what types of bee products have been collected...
# 4    are there any worker bees currently active in ...
# ..                                                 ...
# 507                    what's the egg production like?
# 508          what is the status of drones in the hive?
# 509  how many honey frames are currently filled in ...
# 510    is there a queen currently present in the hive?
# 511  can you list the bee products available from t...
#
#                                                answers
# 0    {'text': ['workers exhibit high foraging behav...
# 1        {'text': ['queenright'], 'answer_start': [0]}
# 2    {'text': ['honey frames are heavy with product...
# 3    {'text': ['all ten honey frames being filled']...
# 4    {'text': ['beeswax levels are sufficient'], 'a...
# ..                                                 ...
# 507       {'text': ['few eggs'], 'answer_start': [51]}
# 508  {'text': ['scarce drones'], 'answer_start': [36]}
# 509  {'text': ['seven honey frames poorly stocked']...
# 510  {'text': ['queen not detected'], 'answer_start...
# 511   {'text': ['honey frames'], 'answer_start': [88]}
#
# [512 rows x 5 columns]

# %%
test_transformed['question'][507]
# Out:
# "what's the egg production like?"

# %%
test_transformed['context'][507]
# Out:
# 'queen absent, disorganized workers, scarce drones, few eggs laid, and seven honey frames poorly stocked'

# %%
def data_preparing(df):

    from transformers import AutoTokenizer
    tokenizer = AutoTokenizer.from_pretrained("distilbert-base-cased-distilled-squad")

    questions = [q.strip() for q in df["question"]]
    context = [q.strip() for q in df["context"]]
    inputs = tokenizer(
            questions,
            context,
            max_length=384,
            truncation="only_second",
            return_offsets_mapping=True,
            padding="max_length",
        )

    offset_mapping = inputs.pop("offset_mapping")

    start_positions = []
    end_positions = []
    answers = df['answers']
    for i, offset in enumerate(offset_mapping):
        answer = answers[i]
        start_char = answer["answer_start"][0]
        end_char = answer["answer_start"][0] + len(answer["text"][0])
        sequence_ids = inputs.sequence_ids(i)

        # Find the start and end of the context
        idx = 0
        while sequence_ids[idx] != 1:
            idx += 1
        context_start = idx
        while sequence_ids[idx] == 1:
            idx += 1
        context_end = idx - 1

        # If the answer is not fully inside the context, label it (0, 0)
        if offset[context_start][0] > end_char or offset[context_end][1] < start_char:
            start_positions.append(0)
            end_positions.append(0)
        else:
            # Otherwise it's the start and end token positions
            idx = context_start
            while idx <= context_end and offset[idx][0] <= start_char:
                idx += 1
            start_positions.append(idx - 1)

            idx = context_end
            while idx >= context_start and offset[idx][1] >= end_char:
                idx -= 1
            end_positions.append(idx + 1)

    df["start_positions"] = start_positions
    df["end_positions"] = end_positions

    import pandas as pd
    from datasets import Dataset
    data = {'input_ids': inputs['input_ids'],
            'attention_mask': inputs['attention_mask'],
            'start_positions':start_positions,
            'end_positions': end_positions,
          }
    df = pd.DataFrame(data)
    #df.to_csv('encoding_train.csv',index=False)
    df = Dataset.from_pandas(df)

    return df

# %%
train_prepared = data_preparing(train_transformed)
test_prepared = data_preparing(test_transformed)
valid_prepared = data_preparing(valid_transformed)
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:89: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# tokenizer_config.json:   0%|          | 0.00/49.0 [00:00<?, ?B/s]
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# config.json:   0%|          | 0.00/473 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/213k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/436k [00:00<?, ?B/s]

# %%
from huggingface_hub import notebook_login
notebook_login()
# Out:
# VBox(children=(HTML(value='<center> <img\nsrc=https://huggingface.co/front/assets/huggingface_logo-noborder.sv…

# %%
from datasets import load_metric

# Load the accuracy metric
accuracy_metric = load_metric("accuracy")

def compute_metrics(pred):
    logits = pred.predictions
    start_logits, end_logits = logits
    start_preds = start_logits.argmax(-1)
    end_preds = end_logits.argmax(-1)

    start_labels = pred.label_ids[0]
    end_labels = pred.label_ids[1]

    # Compute the accuracy for start and end positions
    start_acc = accuracy_metric.compute(predictions=start_preds, references=start_labels)
    end_acc = accuracy_metric.compute(predictions=end_preds, references=end_labels)

    # You can average the two accuracy scores for a final metric or report both
    final_acc = (start_acc['accuracy'] + end_acc['accuracy']) / 2

    return {
        'start_accuracy': start_acc['accuracy'],
        'end_accuracy': end_acc['accuracy'],
        'accuracy': final_acc
    }
# Out:
# /usr/local/lib/python3.10/dist-packages/datasets/load.py:759: FutureWarning: The repository for accuracy contains custom code which must be executed to correctly load the metric. You can inspect the repository content at https://raw.githubusercontent.com/huggingface/datasets/2.19.1/metrics/accuracy/accuracy.py
# You can avoid this message in future by passing the argument `trust_remote_code=True`.
# Passing `trust_remote_code=True` will be mandatory to load this metric from the next major release of `datasets`.
#   warnings.warn(

# %%
from transformers import AutoModelForQuestionAnswering, TrainingArguments, Trainer
model = AutoModelForQuestionAnswering.from_pretrained("distilbert-base-cased-distilled-squad")
from transformers import AutoTokenizer
from transformers import DefaultDataCollator


tokenizer = AutoTokenizer.from_pretrained("distilbert-base-cased-distilled-squad")


data_collator = DefaultDataCollator()

training_args = TrainingArguments(
    output_dir="/content/drive/MyDrive/Distelbert",
    evaluation_strategy="epoch",
    save_strategy="epoch",
    learning_rate=2e-5,
    per_device_train_batch_size=32,
    per_device_eval_batch_size=32,
    num_train_epochs=8,
    weight_decay=0.01,
    push_to_hub=True,
    logging_dir='./logs',
    logging_steps = 10,
    load_best_model_at_end=True
)

trainer = Trainer(
    model=model,
    args=training_args,
    train_dataset=train_prepared,
    eval_dataset=valid_prepared,
    tokenizer=tokenizer,
    data_collator=data_collator,
    compute_metrics=compute_metrics


)

trainer.train()
# Out:
# /usr/local/lib/python3.10/dist-packages/transformers/training_args.py:1474: FutureWarning: `evaluation_strategy` is deprecated and will be removed in version 4.46 of 🤗 Transformers. Use `eval_strategy` instead
#   warnings.warn(
#     <div>
#
#       <progress value='600' max='600' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [600/600 12:22, Epoch 8/8]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Start Accuracy</th>
#       <th>End Accuracy</th>
#       <th>Accuracy</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>0.112300</td>
#       <td>0.204825</td>
#       <td>0.962891</td>
#       <td>0.931641</td>
#       <td>0.947266</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.137700</td>
#       <td>0.125350</td>
#       <td>0.972656</td>
#       <td>0.960938</td>
#       <td>0.966797</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.077500</td>
#       <td>0.102936</td>
#       <td>0.974609</td>
#       <td>0.964844</td>
#       <td>0.969727</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.032000</td>
#       <td>0.102951</td>
#       <td>0.982422</td>
#       <td>0.966797</td>
#       <td>0.974609</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.039700</td>
#       <td>0.089065</td>
#       <td>0.982422</td>
#       <td>0.974609</td>
#       <td>0.978516</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.025000</td>
#       <td>0.084397</td>
#       <td>0.984375</td>
#       <td>0.980469</td>
#       <td>0.982422</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.014500</td>
#       <td>0.084523</td>
#       <td>0.984375</td>
#       <td>0.978516</td>
#       <td>0.981445</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.014700</td>
#       <td>0.081586</td>
#       <td>0.984375</td>
#       <td>0.980469</td>
#       <td>0.982422</td>
#     </tr>
#   </tbody>
# </table><p>
# TrainOutput(global_step=600, training_loss=0.08255062973747651, metrics={'train_runtime': 743.4113, 'train_samples_per_second': 25.687, 'train_steps_per_second': 0.807, 'total_flos': 1871213698658304.0, 'train_loss': 0.08255062973747651, 'epoch': 8.0})

# %%
model.save_pretrained
tokenizer.save_pretrained
# Out:
# <bound method PreTrainedTokenizerBase.save_pretrained of DistilBertTokenizerFast(name_or_path='distilbert-base-cased-distilled-squad', vocab_size=28996, model_max_length=512, is_fast=True, padding_side='right', truncation_side='right', special_tokens={'unk_token': '[UNK]', 'sep_token': '[SEP]', 'pad_token': '[PAD]', 'cls_token': '[CLS]', 'mask_token': '[MASK]'}, clean_up_tokenization_spaces=True),  added_tokens_decoder={
# 	0: AddedToken("[PAD]", rstrip=False, lstrip=False, single_word=False, normalized=False, special=True),
# 	100: AddedToken("[UNK]", rstrip=False, lstrip=False, single_word=False, normalized=False, special=True),
# 	101: AddedToken("[CLS]", rstrip=False, lstrip=False, single_word=False, normalized=False, special=True),
# 	102: AddedToken("[SEP]", rstrip=False, lstrip=False, single_word=False, normalized=False, special=True),
# 	103: AddedToken("[MASK]", rstrip=False, lstrip=False, single_word=False, normalized=False, special=True),
# }>

# %%
output = []
context_dict = {}

for index, row in test_df.iterrows():
    context = row['sentence']
    question = row['question']
    answer = row['answer']

    if context not in context_dict:
        context_dict[context] = {'context': context, 'questions': []}

    context_dict[context]['questions'].append({'question': question, 'answer': answer})

output = list(context_dict.values())

# Display the transformed data
print(output)
# Out:
# [{'context': 'queen absent, disorganized workers, minimal drones, scarce eggs, and six frames underdeveloped', 'questions': [{'question': 'what is the status of workers in the hive?', 'answer': 'disorganized workers'}, {'question': 'how many honey frames are currently filled in the hive?', 'answer': 'six frames underdeveloped'}]}, {'context': 'queen excellent, brood numerous, forage plentiful, eight honey frames topped', 'questions': [{'question': 'what is the current health status of the hive?', 'answer': 'queen excellent'}, {'question': 'describe the foraging behavior observed in the worker bees lately?', 'answer': 'forage plentiful'}, {'question': 'what is the status of the queen in the hive?', 'answer': 'queen excellent'}, {'question': "describe the queen's activity or presence noted in the recent observations?", 'answer': 'queen excellent'}]}, {'context': 'new queen, workers adapting, increasing drone presence, eggs starting to populate, and seven honey frames capped', 'questions': [{'question': 'are there any worker bees currently active in the hive?', 'answer': 'workers adapting'}]}, {'context': 'queen missing, workers slow, drones barely present, low egg production, and three frames with minimal honey', 'questions': [{'question': 'how many honey frames are currently filled in the hive?', 'answer': 'three frames with minimal honey'}, {'question': 'what is the status of the queen in the hive?', 'answer': 'queen missing'}, {'question': 'are there any worker bees currently active in the hive?', 'answer': 'workers slow'}]}, {'context': 'queen unseen, workers managing, drones limited, eggs sporadic, with five honey frames in progress', 'questions': [{'question': 'what is the egg count of the hive?', 'answer': 'eggs sporadic'}]}, {'context': 'queen not found, minimal worker activity, down drone count, slow egg production, and two frames needing attention', 'questions': [{'question': 'what is the current health status of the hive?', 'answer': 'queen not found'}, {'question': 'what is the egg count of the hive?', 'answer': 'low egg production'}, {'question': 'are there any worker bees currently active in the hive?', 'answer': 'minimal worker activity'}]}, {'context': 'queen prolific, brood dense, abundant forage, ten honey frames harvested', 'questions': [{'question': 'describe the foraging behavior observed in the worker bees lately?', 'answer': 'abundant forage'}, {'question': "what's the egg production like?", 'answer': 'brood dense'}]}, {'context': 'strong queen, robust brood, excellent pollen and nectar, nine full honey frames', 'questions': [{'question': "describe the queen's activity or presence noted in the recent observations?", 'answer': 'strong queen'}, {'question': 'describe the foraging behavior observed in the worker bees lately?', 'answer': 'nectar'}, {'question': 'can you estimate how many frames are ready for harvest?', 'answer': 'nine full honey frames'}]}, {'context': 'queen old, workers steady, drone numbers fair, eggs moderate, and five honey frames filled', 'questions': [{'question': 'how many honey frames are currently filled in the hive?', 'answer': 'five honey frames filled'}, {'question': 'what is the status of workers in the hive?', 'answer': 'workers steady'}]}, {'context': 'queen is old but active, workers are steady, good pollen reserves, adequate egg laying observed, and four honey frames fully capped', 'questions': [{'question': 'what is the status of workers in the hive?', 'answer': 'workers are steady'}, {'question': 'describe the foraging behavior observed in the worker bees lately?', 'answer': 'good pollen reserves'}]}, {'context': 'no queen detected, workers disoriented, few drones, minimal egg laying, and only two honey frames filled', 'questions': [{'question': 'what is the status of drones in the hive?', 'answer': 'few drones'}, {'question': 'what is the status of workers in the hive?', 'answer': 'workers disoriented'}]}, {'context': 'queen old, steady workers, fair drone numbers, moderat ...

# %%
#bert_model    = "bert-large-uncased-whole-word-masking-finetuned-squad"
dbert_model   = "distilbert-base-cased-distilled-squad"

# %%
tokenizer = AutoTokenizer.from_pretrained("distilbert-base-cased-distilled-squad")

# %%
models = [
  #bert_model,
  dbert_model
]

# %%
certainty_threshold = 0.15

# %%
def create_pipeline(model):
  return pipeline(
      "question-answering",
      model=model,
      tokenizer=model
  )

# %%
def generate_answers(pipeline, questions, context):
    global certainty_threshold
    score = 0
    correct_predictions = 0
    wrong_predictions = 0
    redundant_predictions = 0

    for obj in questions:
        question = obj['question']
        actual_answer = obj['answer']
        prediction = ''
        print("Question: ", question)

        result = pipeline(question=question, context=context)
        prediction = result['answer']
        confidence = result['score']

        print("Prediction: ", prediction, "Result Score: ", confidence, '\t|\t', "Answer: ", actual_answer)
        score += confidence

        # Check if the prediction is correct, wrong, or redundant
        if prediction.strip().lower() in actual_answer.strip().lower():
            correct_predictions += 1
        elif confidence < certainty_threshold:
            redundant_predictions += 1
        else:
            wrong_predictions += 1

    return score, correct_predictions, wrong_predictions, redundant_predictions

# %%
from transformers import pipeline

model_path = "/content/drive/MyDrive/Distelbert"

# Load the model
dbert_model = AutoModelForQuestionAnswering.from_pretrained(model_path)

# Load the tokenizer
tokenizer = AutoTokenizer.from_pretrained(model_path)

pipelines = []

for model in models:
    print(model)
    pipelines.append(pipeline('question-answering', model=model,  tokenizer=tokenizer))

for ind, ppl in enumerate(pipelines):
    print('\n----------------')
    print(models[ind])
    print('----------------\n')
    total_score = 0
    total_correct_predictions = 0
    total_wrong_predictions = 0
    total_redundant_predictions = 0
    total_questions = 0

    for data in output:
        print('')
        print("Sentence: ", data['context'])
        score, correct_predictions, wrong_predictions, redundant_predictions = generate_answers(ppl, data['questions'], data['context'])
        total_score += score
        total_correct_predictions += correct_predictions
        total_wrong_predictions += wrong_predictions
        total_redundant_predictions += redundant_predictions
        total_questions += len(data['questions'])

    accuracy = total_correct_predictions / total_questions
    print('\n----------------')
    print(f'Score: {total_score}')
    print(f'Accuracy: {accuracy * 100:.2f}%')
    print(f'Correct Answers: {total_correct_predictions / total_questions * 100:.2f}%')
    print(f'Wrong Answers: {total_wrong_predictions / total_questions * 100:.2f}%')
    print(f'Redundant Answers: {total_redundant_predictions / total_questions * 100:.2f}%')
    print('----------------\n')
# Out:
# DistilBertForQuestionAnswering(
#   (distilbert): DistilBertModel(
#     (embeddings): Embeddings(
#       (word_embeddings): Embedding(28996, 768, padding_idx=0)
#       (position_embeddings): Embedding(512, 768)
#       (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#       (dropout): Dropout(p=0.1, inplace=False)
#     )
#     (transformer): Transformer(
#       (layer): ModuleList(
#         (0-5): 6 x TransformerBlock(
#           (attention): MultiHeadSelfAttention(
#             (dropout): Dropout(p=0.1, inplace=False)
#             (q_lin): Linear(in_features=768, out_features=768, bias=True)
#             (k_lin): Linear(in_features=768, out_features=768, bias=True)
#             (v_lin): Linear(in_features=768, out_features=768, bias=True)
#             (out_lin): Linear(in_features=768, out_features=768, bias=True)
#           )
#           (sa_layer_norm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#           (ffn): FFN(
#             (dropout): Dropout(p=0.1, inplace=False)
#             (lin1): Linear(in_features=768, out_features=3072, bias=True)
#             (lin2): Linear(in_features=3072, out_features=768, bias=True)
#             (activation): GELUActivation()
#           )
#           (output_layer_norm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#         )
#       )
#     )
#   )
#   (qa_outputs): Linear(in_features=768, out_features=2, bias=True)
#   (dropout): Dropout(p=0.1, inplace=False)
# )
#
# ----------------
# DistilBertForQuestionAnswering(
#   (distilbert): DistilBertModel(
#     (embeddings): Embeddings(
#       (word_embeddings): Embedding(28996, 768, padding_idx=0)
#       (position_embeddings): Embedding(512, 768)
#       (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#       (dropout): Dropout(p=0.1, inplace=False)
#     )
#     (transformer): Transformer(
#       (layer): ModuleList(
#         (0-5): 6 x TransformerBlock(
#           (attention): MultiHeadSelfAttention(
#             (dropout): Dropout(p=0.1, inplace=False)
#             (q_lin): Linear(in_features=768, out_features=768, bias=True)
#             (k_lin): Linear(in_features=768, out_features=768, bias=True)
#             (v_lin): Linear(in_features=768, out_features=768, bias=True)
#             (out_lin): Linear(in_features=768, out_features=768, bias=True)
#           )
#           (sa_layer_norm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#           (ffn): FFN(
#             (dropout): Dropout(p=0.1, inplace=False)
#             (lin1): Linear(in_features=768, out_features=3072, bias=True)
#             (lin2): Linear(in_features=3072, out_features=768, bias=True)
#             (activation): GELUActivation()
#           )
#           (output_layer_norm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#         )
#       )
#     )
#   )
#   (qa_outputs): Linear(in_features=768, out_features=2, bias=True)
#   (dropout): Dropout(p=0.1, inplace=False)
# )
# ----------------
#
#
# Sentence:  queen absent, disorganized workers, minimal drones, scarce eggs, and six frames underdeveloped
# Question:  what is the status of workers in the hive?
# Prediction:  disorganized workers Result Score:  0.9999688863754272 	|	 Answer:  disorganized workers
# Question:  how many honey frames are currently filled in the hive?
# Prediction:  six frames underdeveloped Result Score:  0.9999912977218628 	|	 Answer:  six frames underdeveloped
#
# Sentence:  queen excellent, brood numerous, forage plentiful, eight honey frames topped
# Question:  what is the current health status of the hive?
# Prediction:  queen excellent Result Score:  0.9999102354049683 	|	 Answer:  queen excellent
# Question:  describe the foraging behavior observed in the worker bees lately?
# Prediction:  forage plentiful Result Score:  0.9999613761901855 	|	 Answer:  forage plentiful
# Question:  what is the status of the queen in the hive?
# Prediction:  queen excellent Result Score:  0.999935507774353 	|	 Answer:  queen excellent
# Question:  describe the queen's activity or presence noted in the recent observations?
# Prediction:  queen excellent Result Score:  0.9999072551727295 	|	 Answer:  queen excellent
#
# Sentence:  new queen, workers adapting, increasing drone presence, eggs starting to populate, and seven honey frames capped
# Question:  are there any worker bees currently active in the hive?
# Prediction:  workers adapting Result Score:  0.99997878074646 	|	 Answer:  workers adapting
#
# Sentence:  queen missing, workers slow, drones barely present, low egg production, and three frames with minimal honey
# Question:  how many honey frames are currently filled in the hive?
# Prediction:  three frames with minimal honey Result Score:  0.9999840259552002 	|	 Answer:  three frames with minimal honey
# Question:  what is the status of the queen in the hive?
# Prediction:  queen missing Result Score:  0.999962568283081 	|	 Answer:  queen missing
# Question:  are there any worker bees currently active in the hive?
# Prediction:  workers slow Result Score:  0.9999001026153564 	|	 Answer:  workers slow
#
# Sentence:  queen unseen, workers managing, drones limited, eggs sporadic, with five honey frames in progress
# Question:  what is the egg count of the hive?
# Prediction:  eggs sporadic Result Score:  0.9998573064804077 	|	 Answer:  eggs sporadic
#
# Sentence:  queen not found, minimal worker activity, down drone count, slow egg production, and two frames needing attention
# Question:  what is the current health status of the hive?
# Prediction:  queen not found Result Score:  0.9999896287918091 	|	 Answer:  queen not found
# Question:  what is the egg count of the hive?
# Prediction:  slow egg production Result Score:  0.999983549118042 	|	 Answer:  low egg production
# Question:  are there any worker bees currently active in the hive?
# Prediction:  minimal worker activity Result Score:  0.9999727010726929 	|	 Answer:  minimal worker activity
#
# Sentence:  queen prolific, brood dense, abundant forage, ten honey frames harvested
# Question:  describe the foraging behavior observed in the worker bees lately?
# Prediction:  abundant forage Result Score:  0.9999932050704956 	|	 Answer:  abundant forage
# Question:  what's the egg production like?
# Prediction:  brood dense Result Score:  0.9999618530273438 	|	 Answer:  brood dense
#
# Sentence:  strong queen, robust brood, excellent pollen and nectar, nine full honey frames
# Question:  describe the queen's activity or presence noted in the recent observations?
# Prediction:  strong queen Result Score:  0.9999020099639893 	|	 Answer:  strong queen
# Question:  describe the foraging behavior observed in the worker bees lately?
# Prediction:  excellent pollen Result Score:  0.9256532192230225 	|	 Answer:  nectar
# Question:  can you estimate how many frames are ready for harvest?
# Prediction:  nine full honey frames Result Score:  0.999790370464325 	|	 Answer:  nine full honey frames
#
# Sentence:  queen old, workers steady, drone numbers fair, eggs moderate, and five honey frames filled
# Question:  how many honey frames are currently filled in the hive?
# Prediction:  five honey frames filled Result Score:  0.9999722242355347 	|	 Answer:  five honey frames filled
# Question:  what is the status of workers in the hive?
# Prediction:  workers steady Result Score:  0.9999407529830933 	|	 Answer:  workers steady
#
# Sentence:  queen is old but active, workers are steady, good pollen reserves, adequate egg laying observed, and four honey frames fully capped
# Question:  what is the status of workers in the hive?
# Prediction:  workers are steady Result Score:  0.9997125267982483 	|	 Answer:  workers are steady
# Question:  describe the foraging behavior observed in the worker bees lately?
# Prediction:  good pollen reserves Result Score:  0.9988570213317871 	|	 Answer:  good pollen reserves
#
# Sentence:  no queen detected, workers disoriented, few drones, minimal egg laying, and only two honey frames filled
# Question:  what is the status of drones in the hive?
# Prediction:  few drones Result Score:  0.9999737739562988 	|	 Answer:  few drones
# Question:  what is the status of workers in the hive?
# Prediction:  workers disoriented Result Score:  0.9999814033508301 	|	 Answer:  workers disoriented
#
# Sentence:  queen old, steady workers, fair drone numbers, moderate eggs, and five honey frames filled
# Question:  what is the status of workers in the hive?
# Prediction:  steady workers Result Score:  0.999990701675415 	|	 Answer:  steady workers
# Question:  is there a queen currently present in the hive?
# Prediction:  queen old Result Score:  0.9999676942825317 	|	 Answer:  queen old
#
# Sentence:  queen missing, workers sluggish, few drones, scarce eggs, and four honey frames underfilled
# Question:  what's the egg production like?
# Prediction:  scarce eggs Result Score:  0.9999892711639404 	|	 Answer:  scarce eggs
# Question:  what is the status of drones in the hive?
# Prediction:  few drones Result Score:  0.9999626874923706 	|	 Answer:  few drones
# Question:  what types of bee products have been collected recently?
# Prediction:  honey frames underfilled Result Score:  0.9895786046981812 	|	 Answer:  honey frames underfilled
#
# Sentence:  queen aging, steady workers, few drones, moderate eggs, and six honey frames nearing capacity
# Question:  what is the status of the queen in the hive?
# Prediction:  queen aging Result Score:  0.9999618530273438 	|	 Answer:  queen aging
# Question:  is there a queen currently present in the hive?
# Prediction:  queen aging Result Score:  0.9999250173568726 	|	 Answer:  queen aging
# Question:  how many honey frames are currently filled in the hive?
# Prediction:  six honey frames nearing capacity Result Score:  0.9999916553497314 	|	 Answer:  six honey frames nearing capacity
# Question:  what is the current health status of the hive?
# Prediction:  queen aging Result Score:  0.9999630451202393 	|	 Answer:  queen aging
#
# Sentence:  queen healthy, hardworking workers, ample drones, prolific eggs, with eight honey frames perfectly capped
# Question:  what's the egg production like?
# Prediction:  prolific eggs Result Score:  0.9999825954437256 	|	 Answer:  prolific eggs
# Question:  can you list the bee products available from the latest harvest?
# Prediction:  with eight honey frames perfectly capped Result Score:  0.9998582601547241 	|	 Answer:  with eight honey frames perfectly capped
# Question:  are there any worker bees currently active in the hive?
# Prediction:  hardworking workers Result Score:  0.9999877214431763 	|	 Answer:  hardworking workers
# Question:  what is the status of workers in the hive?
# Prediction:  hardworking workers Result Score:  0.9999715089797974 	|	 Answer:  hardworking workers
#
# Sentence:  queen observed, workers active, drones plentiful, eggs numerous, and nine honey frames full
# Question:  what is the status of the queen in the hive?
# Prediction:  queen observed Result Score:  0.9999188184738159 	|	 Answer:  queen observed
# Question:  are there any worker bees currently active in the hive?
# Prediction:  workers active Result Score:  0.9999290704727173 	|	 Answer:  workers active
# Question:  what types of bee products have been collected recently?
# Prediction:  nine honey frames full Result Score:  0.9999774694442749 	|	 Answer:  nine honey frames full
#
# Sentence:  newly emerged queen, workers adjusting, building drone numbers, good egg production, and five honey frames capped
# Question:  what's the egg production like?
# Prediction:  good egg production Result Score:  0.9999889135360718 	|	 Answer:  good egg production
# Question:  what is the status of drones in the hive?
# Prediction:  building drone numbers Result Score:  0.9999948740005493 	|	 Answer:  building drone numbers
#
# Sentence:  queen absent, replacing, workers active, six honey frames being filled
# Question:  what is the current health status of the hive?
# Prediction:  queen absent Result Score:  0.9999880790710449 	|	 Answer:  queen absent
#
# Sentence:  queen vibrant, workers industrious, drones healthy, eggs abundant, and eleven frames heavy with honey
# Question:  what is the status of workers in the hive?
# Prediction:  workers industrious Result Score:  0.9999924898147583 	|	 Answer:  workers industrious
# Question:  can you estimate how many frames are ready for harvest?
# Prediction:  eleven frames heavy with honey Result Score:  0.9999539852142334 	|	 Answer:  eleven frames heavy with honey
# Question:  what types of bee products have been collected recently?
# Prediction:  eleven frames heavy with honey Result Score:  0.9999762773513794 	|	 Answer:  eleven frames heavy with honey
# Question:  what is the current health status of the hive?
# Prediction:  queen vibrant Result Score:  0.9999517202377319 	|	 Answer:  queen vibrant
#
# Sentence:  a newly emerged queen already proving her worth, workers efficiently managing the nectar flow despite the recent dry spell, and honey frames well on their way to being filled to the brim
# Question:  can you estimate how many frames are ready for harvest?
# Prediction:  honey frames well on their way to being filled to the brim Result Score:  0.9997794032096863 	|	 Answer:  honey frames well on their way to being filled to the brim
# Question:  what is the status of workers in the hive?
# Prediction:  workers efficiently Result Score:  0.9964264035224915 	|	 Answer:  workers efficient
#
# Sentence:  queen not found, worker activity minimal, drone count reduced, egg laying uncertain, honey production on five frames stalled
# Question:  what is the status of drones in the hive?
# Prediction:  drone count reduced Result Score:  0.9999908208847046 	|	 Answer:  drone count reduced
# Question:  can you estimate how many frames are ready for harvest?
# Prediction:  honey production on five frames stalled Result Score:  0.995760440826416 	|	 Answer:  honey production on five frames stalled
# Question:  describe the queen's activity or presence noted in the recent observations?
# Prediction:  queen not found Result Score:  0.9999598264694214 	|	 Answer:  queen not found
#
# Sentence:  queen present, strong brood, ample pollen and nectar, ten frames of honey
# Question:  what types of forage bees have been foraging?
# Prediction:  ample pollen Result Score:  0.8243269324302673 	|	 Answer:  nectar
# Question:  what's the egg production like?
# Prediction:  strong brood Result Score:  0.9999819993972778 	|	 Answer:  strong brood
# Question:  what is the status of the queen in the hive?
# Prediction:  queen present Result Score:  0.9999817609786987 	|	 Answer:  queen present
# Question:  can you list the bee products available from the latest harvest?
# Prediction:  ten frames of honey Result Score:  0.9997877478599548 	|	 Answer:  ten frames of honey
# Question:  what is the egg count of the hive?
# Prediction:  strong brood Result Score:  0.9999748468399048 	|	 Answer:  strong brood
#
# Sentence:  queen in prime, abundant worker bees, drone activity normal, eggs plentiful, and six frames laden with honey
# Question:  can you list the bee products available from the latest harvest?
# Prediction:  frames laden with honey Result Score:  0.9398784041404724 	|	 Answer:  frames laden with honey
# Question:  what is the egg count of the hive?
# Prediction:  eggs plentiful Result Score:  0.9999785423278809 	|	 Answer:  eggs plentiful
#
# Sentence:  queen weak, slow workers, few drones, limited eggs, and six frames partially filled with honey
# Question:  what is the current health status of the hive?
# Prediction:  queen weak Result Score:  0.9999549388885498 	|	 Answer:  queen weak
# Question:  what is the status of the queen in the hive?
# Prediction:  queen weak Result Score:  0.9999666213989258 	|	 Answer:  queen weak
#
# Sentence:  queen strong, workers busy, healthy drones, eggs abundant, and nine frames heavy with honey
# Question:  what's the egg production like?
# Prediction:  eggs abundant Result Score:  0.9999856948852539 	|	 Answer:  eggs abundant
# Question:  what types of bee products have been collected recently?
# Prediction:  nine frames heavy with honey Result Score:  0.9999821186065674 	|	 Answer:  nine frames heavy with honey
#
# Sentence:  queen productive, worker bees energetic, drones plentiful, eggs abounding, and nine frames filled with honey
# Question:  what is the status of the queen in the hive?
# Prediction:  queen productive Result Score:  0.9999721050262451 	|	 Answer:  queen productive
# Question:  is there a queen currently present in the hive?
# Prediction:  queen productive Result Score:  0.9999481439590454 	|	 Answer:  queen productive
#
# Sentence:  queen strong, worker bees numerous, drones healthy, eggs abundant, and nine frames heavy with honey
# Question:  what is the status of the queen in the hive?
# Prediction:  queen strong Result Score:  0.9999639987945557 	|	 Answer:  queen strong
# Question:  what types of bee products have been collected recently?
# Prediction:  nine frames heavy with honey Result Score:  0.999983549118042 	|	 Answer:  nine frames heavy with honey
#
# Sentence:  queen energetic, workers highly active, drones numerous, eggs prolific, with eight honey frames capped
# Question:  are there any worker bees currently active in the hive?
# Prediction:  workers highly active Result Score:  0.9999871253967285 	|	 Answer:  workers highly active
# Question:  is there a queen currently present in the hive?
# Prediction:  queen energetic Result Score:  0.9999287128448486 	|	 Answer:  queen energetic
# Question:  what is the egg count of the hive?
# Prediction:  eggs prolific Result Score:  0.9999525547027588 	|	 Answer:  eggs prolific
#
# Sentence:  queen robust, workers active, ample drones, good egg production, and ten frames well-stocked with honey
# Question:  describe the queen's activity or presence noted in the recent observations?
# Prediction:  queen robust Result Score:  0.9999216794967651 	|	 Answer:  queen robust
# Question:  what's the egg production like?
# Prediction:  good egg production Result Score:  0.9999841451644897 	|	 Answer:  good egg production
# Question:  what is the current health status of the hive?
# Prediction:  queen robust Result Score:  0.9999294281005859 	|	 Answer:  queen robust
# Question:  is there a queen currently present in the hive?
# Prediction:  queen robust Result Score:  0.9999394416809082 	|	 Answer:  queen robust
#
# Sentence:  queen healthy, workers bustling, drones plentiful, eggs numerous, and ten frames brimming with honey
# Question:  what's the egg production like?
# Prediction:  eggs numerous Result Score:  0.9999548196792603 	|	 Answer:  eggs numerous
# Question:  are there any worker bees currently active in the hive?
# Prediction:  workers bustling Result Score:  0.999994158744812 	|	 Answer:  workers bustling
# Question:  describe the queen's activity or presence noted in the recent observations?
# Prediction:  queen healthy Result Score:  0.9998465776443481 	|	 Answer:  queen healthy
#
# Sentence:  queen healthy, strong worker activity, ample drones, high egg count, and seven honey frames fully capped
# Question:  describe the queen's activity or presence noted in the recent observations?
# Prediction:  queen healthy Result Score:  0.9998865127563477 	|	 Answer:  queen healthy
# Question:  can you list the bee products available from the latest harvest?
# Prediction:  honey frames Result Score:  0.9994387030601501 	|	 Answer:  honey frames
# Question:  what types of bee products have been collected recently?
# Prediction:  honey frames Result Score:  0.9994984865188599 	|	 Answer:  honey frames
#
# Sentence:  queen vibrant, full brood chamber, high forage activity, ten honey frames heavy
# Question:  describe the queen's activity or presence noted in the recent observations?
# Prediction:  queen vibrant Result Score:  0.9999607801437378 	|	 Answer:  queen vibrant
# Question:  how many honey frames are currently filled in the hive?
# Prediction:  ten honey frames heavy Result Score:  0.9999959468841553 	|	 Answer:  ten honey frames heavy
#
# Sentence:  queen observed, workers efficient, drones active, high egg count, and nine honey frames fully utilized
# Question:  what is the status of drones in the hive?
# Prediction:  drones active Result Score:  0.9998959302902222 	|	 Answer:  drones active
# Question:  can you list the bee products available from the latest harvest?
# Prediction:  nine honey frames fully utilized Result Score:  0.999729573726654 	|	 Answer:  nine honey frames fully utilized
# Question:  how many honey frames are currently filled in the hive?
# Prediction:  nine honey frames fully utilized Result Score:  0.9999847412109375 	|	 Answer:  nine honey frames fully utilized
#
# Sentence:  queen efficient, busy workers, good drone activity, plentiful eggs, and eight frames ready for extraction
# Question:  what is the status of workers in the hive?
# Prediction:  busy workers Result Score:  0.9999760389328003 	|	 Answer:  busy workers
# Question:  what is the status of drones in the hive?
# Prediction:  good drone activity Result Score:  0.999991774559021 	|	 Answer:  good drone activity
# Question:  what is the egg count of the hive?
# Prediction:  plentiful eggs Result Score:  0.9999046325683594 	|	 Answer:  plentiful eggs
# Question:  what is the current health status of the hive?
# Prediction:  queen efficient Result Score:  0.9999533891677856 	|	 Answer:  queen efficient
#
# Sentence:  queen present, excelling workers, optimal drone count, eggs copious, and all frames teeming with honey
# Question:  describe the queen's activity or presence noted in the recent observations?
# Prediction:  queen present Result Score:  0.9999668598175049 	|	 Answer:  queen present
# Question:  what is the status of workers in the hive?
# Prediction:  excelling workers Result Score:  0.9999890327453613 	|	 Answer:  excelling workers
#
# Sentence:  queen visible, workers energetic, sufficient drones, numerous eggs, and eight frames filled with honey
# Question:  what's the egg production like?
# Prediction:  numerous eggs Result Score:  0.9999771118164062 	|	 Answer:  numerous eggs
# Question:  are there any worker bees currently active in the hive?
# Prediction:  workers energetic Result Score:  0.9999827146530151 	|	 Answer:  workers energetic
# Question:  what types of bee products have been collected recently?
# Prediction:  eight frames filled with honey Result Score:  0.9999208450317383 	|	 Answer:  eight frames filled with honey
#
# Sentence:  queen absent, disorganized workers, scarce drones, few eggs laid, and five honey frames poorly stocked
# Question:  can you list the bee products available from the latest harvest?
# Prediction:  honey frames poorly stocked Result Score:  0.7894819378852844 	|	 Answer:  five honey frames poorly stocked
# Question:  are there any worker bees currently active in the hive?
# Prediction:  disorganized workers Result Score:  0.9999847412109375 	|	 Answer:  disorganized workers
#
# Sentence:  queen productive, industrious workers, sufficient drones, high egg count, and eight frames capped
# Question:  how many honey frames are currently filled in the hive?
# Prediction:  eight frames capped Result Score:  0.999995231628418 	|	 Answer:  eight frames capped
# Question:  what is the current health status of the hive?
# Prediction:  queen productive Result Score:  0.9998718500137329 	|	 Answer:  queen productive
# Question:  what is the status of workers in the hive?
# Prediction:  industrious workers Result Score:  0.9999858140945435 	|	 Answer:  industrious workers
# Question:  can you estimate how many frames are ready for harvest?
# Prediction:  eight frames capped Result Score:  0.9999918937683105 	|	 Answer:  eight frames capped
# Question:  are there any worker bees currently active in the hive?
# Prediction:  industrious workers Result Score:  0.9999901056289673 	|	 Answer:  industrious workers
#
# Sentence:  queen seen, workers industrious, drone presence good, egg laying on track, with seven frames filled with honey
# Question:  what is the status of workers in the hive?
# Prediction:  workers industrious Result Score:  0.9999945163726807 	|	 Answer:  workers industrious
#
# Sentence:  queen not found, workers listless, low forage, two honey frames empty
# Question:  what is the status of workers in the hive?
# Prediction:  workers listless Result Score:  0.99988853931427 	|	 Answer:  workers listless
# Question:  are there any worker bees currently active in the hive?
# Prediction:  workers listless Result Score:  0.9999716281890869 	|	 Answer:  workers listless
# Question:  what types of bee products have been collected recently?
# Prediction:  honey frames empty Result Score:  0.9841243624687195 	|	 Answer:  honey frames empty
# Question:  what is the status of the queen in the hive?
# Prediction:  queen not found Result Score:  0.9999898672103882 	|	 Answer:  queen not found
#
# Sentence:  queen visible and healthy, thriving workers, ample drones, abundant eggs, and ten frames densely packed with honey
# Question:  how many honey frames are currently filled in the hive?
# Prediction:  ten frames densely packed with honey Result Score:  0.9999916553497314 	|	 Answer:  ten frames densely packed with honey
# Question:  is there a queen currently present in the hive?
# Prediction:  queen visible Result Score:  0.999955415725708 	|	 Answer:  queen visible
# Question:  are there any worker bees currently active in the hive?
# Prediction:  thriving workers Result Score:  0.9999632835388184 	|	 Answer:  thriving workers
# Question:  describe the queen's activity or presence noted in the recent observations?
# Prediction:  queen visible Result Score:  0.9999405145645142 	|	 Answer:  queen visible
#
# Sentence:  queen active, worker bees numerous, drone count normal, eggs abundant, propolis and six honey frames collected
# Question:  how many honey frames are currently filled in the hive?
# Prediction:  six honey frames collected Result Score:  0.9999815225601196 	|	 Answer:  six honey frames collected
# Question:  are there any worker bees currently active in the hive?
# Prediction:  worker bees numerous Result Score:  0.9996626377105713 	|	 Answer:  worker bees numerous
# Question:  what is the status of drones in the hive?
# Prediction:  drone count normal Result Score:  0.9999896287918091 	|	 Answer:  drone count normal
# Question:  can you estimate how many frames are ready for harvest?
# Prediction:  six honey frames collected Result Score:  0.9999935626983643 	|	 Answer:  six honey frames collected
#
# Sentence:  queen missing, lethargic workers, disappearing drones, scarce eggs, and only five frames showing some honey
# Question:  can you estimate how many frames are ready for harvest?
# Prediction:  only five frames showing some honey Result Score:  0.9999852180480957 	|	 Answer:  only five frames showing some honey
# Question:  what is the status of drones in the hive?
# Prediction:  disappearing drones Result Score:  0.9999918937683105 	|	 Answer:  disappearing drones
# Question:  what types of bee products have been collected recently?
# Prediction:  frames Result Score:  0.5492770671844482 	|	 Answer:  frames
# Question:  describe the queen's activity or presence noted in the recent observations?
# Prediction:  queen missing Result Score:  0.9999536275863647 	|	 Answer:  queen missing
#
# Sentence:  queen not found, worker bees sluggish, drone numbers low, egg count down, but still five frames of honey
# Question:  what is the egg count of the hive?
# Prediction:  egg count down Result Score:  0.99982750415802 	|	 Answer:  egg count down
# Question:  what is the status of workers in the hive?
# Prediction:  worker bees sluggish Result Score:  0.9999728202819824 	|	 Answer:  worker bees sluggish
#
# Sentence:  newly mated queen, adjusting workers, increasing drone activity, beginning egg population, with eight frames nearing capacity
# Question:  can you estimate how many frames are ready for harvest?
# Prediction:  with eight frames nearing capacity Result Score:  0.9999898672103882 	|	 Answer:  with eight frames nearing capacity
#
# Sentence:  queen vibrant, energetic workers, active drones, abundant eggs, and all frames filled to capacity
# Question:  what is the status of drones in the hive?
# Prediction:  active drones Result Score:  0.9999876022338867 	|	 Answer:  active drones
# Question:  what is the status of workers in the hive?
# Prediction:  energetic workers Result Score:  0.9999878406524658 	|	 Answer:  energetic workers
#
# Sentence:  queen absent, worker bees disoriented, few drones seen, eggs scarce, and only four honey frames partially capped
# Question:  describe the queen's activity or presence noted in the recent observations?
# Prediction:  queen absent Result Score:  0.9999855756759644 	|	 Answer:  queen absent
# Question:  what is the status of the queen in the hive?
# Prediction:  queen absent Result Score:  0.9999874830245972 	|	 Answer:  queen absent
# Question:  what is the status of drones in the hive?
# Prediction:  few drones seen Result Score:  0.9777736663818359 	|	 Answer:  few drones seen
# Question:  how many honey frames are currently filled in the hive?
# Prediction:  only four honey frames partially capped Result Score:  0.9999781847000122 	|	 Answer:  only four honey frames partially capped
# Question:  what is the status of workers in the hive?
# Prediction:  worker bees disoriented Result Score:  0.9999774694442749 	|	 Answer:  worker bees disoriented
#
# Sentence:  queen absent, worker morale low, minimal drones, few eggs, and three honey frames barely used
# Question:  what is the status of drones in the hive?
# Prediction:  minimal drones Result Score:  0.9999781847000122 	|	 Answer:  minimal drones
# Question:  describe the queen's activity or presence noted in the recent observations?
# Prediction:  queen absent Result Score:  0.9999803304672241 	|	 Answer:  queen absent
#
# Sentence:  queen laying well, vibrant workers, active drones, plenty of eggs, and ten honey frames topped
# Question:  what's the egg production like?
# Prediction:  plenty of eggs Result Score:  0.9999940395355225 	|	 Answer:  plenty of eggs
# Question:  what is the status of drones in the hive?
# Prediction:  active drones Result Score:  0.9999860525131226 	|	 Answer:  active drones
#
# Sentence:  queen vibrant, active workers, many drones, well-laid eggs, and nine honey frames capped
# Question:  describe the queen's activity or presence noted in the recent observations?
# Prediction:  queen vibrant Result Score:  0.9999548196792603 	|	 Answer:  queen vibrant
#
# Sentence:  queen absent, workers disorganized, drones minimal, eggs scarce, and three honey frames underdeveloped
# Question:  what is the status of workers in the hive?
# Prediction:  workers disorganized Result Score:  0.9999827146530151 	|	 Answer:  workers disorganized
# Question:  what is the status of the queen in the hive?
# Prediction:  queen absent Result Score:  0.9999792575836182 	|	 Answer:  queen absent
# Question:  what is the current health status of the hive?
# Prediction:  queen absent Result Score:  0.9999806880950928 	|	 Answer:  queen absent
#
# Sentence:  queen visible, active workers, good drone population, plentiful eggs, and eight honey frames filled
# Question:  how many honey frames are currently filled in the hive?
# Prediction:  eight honey frames filled Result Score:  0.9999229907989502 	|	 Answer:  eight honey frames filled
# Question:  what is the current health status of the hive?
# Prediction:  queen visible Result Score:  0.9999725818634033 	|	 Answer:  queen visible
#
# Sentence:  queen active, workers efficient, drone count stable, eggs numerous, beeswax and honey ample on eight frames
# Question:  what's the egg production like?
# Prediction:  eggs numerous Result Score:  0.9999814033508301 	|	 Answer:  eggs numerous
# Question:  can you estimate how many frames are ready for harvest?
# Prediction:  honey ample on eight frames Result Score:  0.9998947381973267 	|	 Answer:  honey ample on eight frames
# Question:  what is the status of the queen in the hive?
# Prediction:  queen active Result Score:  0.9999802112579346 	|	 Answer:  queen active
#
# Sentence:  queen missing, lethargic workers, reduced drone count, poor egg output, and four frames lacking honey
# Question:  what is the status of workers in the hive?
# Prediction:  lethargic workers Result Score:  0.9999690055847168 	|	 Answer:  lethargic workers
#
# Sentence:  queenright with an extensive brood pattern, workers exhibit high foraging behavior, honey stores are high, and seven honey frames are heavy with product
# Question:  what types of forage bees have been foraging?
# Prediction:  workers exhibit high foraging behavior Result Score:  0.9999395608901978 	|	 Answer:  workers exhibit high foraging behavior
# Question:  is there a queen currently present in the hive?
# Prediction:  queenright Result Score:  0.9999746084213257 	|	 Answer:  queenright
# Question:  can you list the bee products available from the latest harvest?
# Prediction:  honey frames are heavy with product Result Score:  0.8387843370437622 	|	 Answer:  honey frames are heavy with product
#
# Sentence:  queen missing, workers lethargic, low drone count, poor egg output, and four frames lacking honey
# Question:  what is the status of drones in the hive?
# Prediction:  low drone count Result Score:  0.9999933242797852 	|	 Answer:  low drone count
# Question:  what is the status of workers in the hive?
# Prediction:  workers lethargic Result Score:  0.9999901056289673 	|	 Answer:  workers lethargic
# Question:  what is the egg count of the hive?
# Prediction:  poor egg output Result Score:  0.9999849796295166 	|	 Answer:  poor egg output
#
# Sentence:  queen robust, workers bustling, drones numerous, eggs filling up cells, and seven frames brimming with honey
# Question:  what is the current health status of the hive?
# Prediction:  queen robust Result Score:  0.9999287128448486 	|	 Answer:  queen robust
# Question:  is there a queen currently present in the hive?
# Prediction:  queen robust Result Score:  0.9999343156814575 	|	 Answer:  queen robust
# Question:  describe the queen's activity or presence noted in the recent observations?
# Prediction:  queen robust Result Score:  0.999933123588562 	|	 Answer:  queen robust
#
# Sentence:  queen struggling, workers doing their best, few drones, low egg count, with five frames partially filled
# Question:  how many honey frames are currently filled in the hive?
# Prediction:  with five frames partially filled Result Score:  0.9999905824661255 	|	 Answer:  with five frames partially filled
# Question:  what is the status of drones in the hive?
# Prediction:  few drones Result Score:  0.9999860525131226 	|	 Answer:  few drones
#
# Sentence:  queen effective, workers busy, good drone count, high egg numbers, plenty of beeswax and eight honey frames filled
# Question:  what types of bee products have been collected recently?
# Prediction:  eight honey frames filled Result Score:  0.9998437166213989 	|	 Answer:  eight honey frames filled
# Question:  what is the status of drones in the hive?
# Prediction:  good drone count Result Score:  0.9999521970748901 	|	 Answer:  good drone count
#
# Sentence:  queen present, brood large, forage excellent, ten frames heavy with honey
# Question:  what's the egg production like?
# Prediction:  brood large Result Score:  0.999943733215332 	|	 Answer:  brood large
# Question:  what types of bee products have been collected recently?
# Prediction:  ten frames heavy with honey Result Score:  0.9997959733009338 	|	 Answer:  ten frames heavy with honey
#
# Sentence:  queen active, workers bustling, drones numerous, eggs plentiful, and ten honey frames well-stocked
# Question:  how many honey frames are currently filled in the hive?
# Prediction:  ten honey frames well-stocked Result Score:  0.9999901056289673 	|	 Answer:  ten honey frames well-stocked
# Question:  describe the queen's activity or presence noted in the recent observations?
# Prediction:  queen active Result Score:  0.9999537467956543 	|	 Answer:  queen active
#
# Sentence:  queen declining, workers maintaining, drones few, egg count low, and three honey frames only half full
# Question:  what's the egg production like?
# Prediction:  egg count low Result Score:  0.999985933303833 	|	 Answer:  egg count low
# Question:  is there a queen currently present in the hive?
# Prediction:  queen declining Result Score:  0.9999692440032959 	|	 Answer:  queen declining
#
# Sentence:  queen laying well, vibrant workers, active drones, many eggs, and ten honey frames topped off
# Question:  what is the egg count of the hive?
# Prediction:  many eggs Result Score:  0.9999686479568481 	|	 Answer:  many eggs
# Question:  what is the status of drones in the hive?
# Prediction:  active drones Result Score:  0.9999858140945435 	|	 Answer:  active drones
#
# Sentence:  queen vibrant, workers industrious, drones adequate, robust egg production, and seven frames filled to the brim with honey
# Question:  what is the current health status of the hive?
# Prediction:  queen vibrant Result Score:  0.9999446868896484 	|	 Answer:  queen vibrant
# Question:  what types of bee products have been collected recently?
# Prediction:  frames Result Score:  0.9963462352752686 	|	 Answer:  frames
# Question:  can you estimate how many frames are ready for harvest?
# Prediction:  seven frames filled to the brim with honey Result Score:  0.9999784231185913 	|	 Answer:  seven frames filled to the brim with honey
#
# Sentence:  queen present, worker numbers strong, drone population up, eggs plentiful, and seven honey frames along with substantial beeswax
# Question:  is there a queen currently present in the hive?
# Prediction:  queen present Result Score:  0.9999850988388062 	|	 Answer:  queen present
# Question:  describe the queen's activity or presence noted in the recent observations?
# Prediction:  queen present Result Score:  0.9999511241912842 	|	 Answer:  queen present
#
# Sentence:  queen laying profusely, high worker and drone activity, egg count high, plenty of honey and beeswax across eight frames
# Question:  what is the status of workers in the hive?
# Prediction:  beeswax across eight frames Result Score:  0.9999066591262817 	|	 Answer:  beeswax across eight frames
# Question:  how many honey frames are currently filled in the hive?
# Prediction:  beeswax across eight frames Result Score:  0.9959158301353455 	|	 Answer:  beeswax across eight frames
# Question:  what is the status of drones in the hive?
# Prediction:  drone activity Result Score:  0.9995599389076233 	|	 Answer:  drone activity
#
# Sentence:  queen missing, lethargic workers, low drone count, poor egg output, and four frames lacking honey
# Question:  what is the current health status of the hive?
# Prediction:  queen missing Result Score:  0.9999514818191528 	|	 Answer:  queen missing
#
# Sentence:  queen not detected, workers disoriented, low drone count, minimal egg laying, and three honey frames underutilized
# Question:  is there a queen currently present in the hive?
# Prediction:  queen not detected Result Score:  0.9999344348907471 	|	 Answer:  queen not detected
# Question:  can you list the bee products available from the latest harvest?
# Prediction:  honey frames underutilized Result Score:  0.7783605456352234 	|	 Answer:  honey frames
#
# Sentence:  queen vibrant, numerous worker  bees, adequate drones, eggs filling up, and eleven honey frames topped off
# Question:  are there any worker bees currently active in the hive?
# Prediction:  numerous worker  bees Result Score:  0.9999780654907227 	|	 Answer:  numerous worker  bees
# Question:  what is the status of workers in the hive?
# Prediction:  numerous worker  bees Result Score:  0.9999839067459106 	|	 Answer:  numerous worker  bees
# Question:  what is the status of the queen in the hive?
# Prediction:  queen vibrant Result Score:  0.9999648332595825 	|	 Answer:  queen vibrant
#
# Sentence:  queen recently replaced, workers rallying, drones emerging, eggs increasing, beeswax and honey ample on nine frames
# Question:  what types of bee products have been collected recently?
# Prediction:  honey ample on nine frames Result Score:  0.9998794794082642 	|	 Answer:  honey ample on nine frames
#
# Sentence:  queen active, abundant workers, healthy drone population, egg production excellent, and seven frames full of honey
# Question:  can you estimate how many frames are ready for harvest?
# Prediction:  seven frames full of honey Result Score:  0.9999731779098511 	|	 Answer:  seven frames full of honey
# Question:  what's the egg production like?
# Prediction:  egg production excellent Result Score:  0.9994521737098694 	|	 Answer:  egg production excellent
#
# Sentence:  queen weak, slow workers, few drones, limited egg production, and six honey frames partially filled
# Question:  describe the queen's activity or presence noted in the recent observations?
# Prediction:  queen weak Result Score:  0.9999136924743652 	|	 Answer:  queen weak
# Question:  what is the status of workers in the hive?
# Prediction:  slow workers Result Score:  0.9999841451644897 	|	 Answer:  slow workers
#
# Sentence:  queen not seen, workers distressed, drone count low, egg production stalling, and only two honey frames filled
# Question:  is there a queen currently present in the hive?
# Prediction:  queen not seen Result Score:  0.9999631643295288 	|	 Answer:  queen not seen
# Question:  what is the status of workers in the hive?
# Prediction:  workers distressed Result Score:  0.9999847412109375 	|	 Answer:  workers distressed
#
# Sentence:  queen weak, slow workers, few drones, limited egg production, and seven honey frames partially filled
# Question:  can you list the bee products available from the latest harvest?
# Prediction:  honey frames Result Score:  0.8367144465446472 	|	 Answer:  honey frames
#
# Sentence:  queen visible and healthy, thriving workers, adequate drones, abundant eggs, and ten frames densely packed with honey
# Question:  are there any worker bees currently active in the hive?
# Prediction:  thriving workers Result Score:  0.9999634027481079 	|	 Answer:  thriving workers
#
# Sentence:  queen newly emerged, workers adjusting, drones building, good egg numbers, and five honey frames capped
# Question:  is there a queen currently present in the hive?
# Prediction:  queen newly emerged Result Score:  0.999947190284729 	|	 Answer:  queen new
# Question:  describe the queen's activity or presence noted in the recent observations?
# Prediction:  queen newly emerged Result Score:  0.999839186668396 	|	 Answer:  queen new
#
# Sentence:  queen efficient, workers busy, good drone population, eggs numerous, and eight honey frames topped up
# Question:  what is the status of workers in the hive?
# Prediction:  workers busy Result Score:  0.9999160766601562 	|	 Answer:  workers busy
# Question:  can you list the bee products available from the latest harvest?
# Prediction:  eight honey frames topped up Result Score:  0.9999434947967529 	|	 Answer:  eight honey frames topped up
# Question:  how many honey frames are currently filled in the hive?
# Prediction:  eight honey frames topped up Result Score:  0.9999734163284302 	|	 Answer:  eight honey frames topped up
#
# Sentence:  queen absent, low worker morale, minimal drones, few eggs, and five honey frames barely touched
# Question:  what is the current health status of the hive?
# Prediction:  queen absent Result Score:  0.9999786615371704 	|	 Answer:  queen absent
# Question:  what is the status of drones in the hive?
# Prediction:  minimal drones Result Score:  0.999983549118042 	|	 Answer:  minimal drones
#
# Sentence:  queen aging, steady workers, reduced drones, moderate eggs, with six frames filled with honey
# Question:  describe the queen's activity or presence noted in the recent observations?
# Prediction:  queen aging Result Score:  0.9998378753662109 	|	 Answer:  queen aging
#
# Sentence:  new queen, workers bustling, abundant forage, six full honey frames
# Question:  what is the current health status of the hive?
# Prediction:  new queen Result Score:  0.9999778270721436 	|	 Answer:  new queen
# Question:  can you list the bee products available from the latest harvest?
# Prediction:  full honey frames Result Score:  0.9997350573539734 	|	 Answer:  full honey frames
# Question:  describe the foraging behavior observed in the worker bees lately?
# Prediction:  abundant forage Result Score:  0.9999395608901978 	|	 Answer:  abundant forage
#
# Sentence:  queen laying well, high worker activity, rich pollen, eight honey frames capped
# Question:  are there any worker bees currently active in the hive?
# Prediction:  high worker activity Result Score:  0.9999473094940186 	|	 Answer:  high worker activity
# Question:  is there a queen currently present in the hive?
# Prediction:  queen laying well Result Score:  0.9997554421424866 	|	 Answer:  queen laying well
#
# Sentence:  queen prolific, workers exceed expectations, drone population optimal, egg count high, and honey abundant in ten frames
# Question:  what is the status of drones in the hive?
# Prediction:  drone population optimal Result Score:  0.9999897480010986 	|	 Answer:  drone population optimal
# Question:  what is the current health status of the hive?
# Prediction:  queen prolific Result Score:  0.9998315572738647 	|	 Answer:  queen prolific
#
# Sentence:  queen old, steady workers, fair drone numbers, moderate eggs, and nine honey frames well-stocked
# Question:  what is the status of drones in the hive?
# Prediction:  fair drone numbers Result Score:  0.999992847442627 	|	 Answer:  fair drone numbers
# Question:  are there any worker bees currently active in the hive?
# Prediction:  steady workers Result Score:  0.9999873638153076 	|	 Answer:  steady workers
# Question:  can you estimate how many frames are ready for harvest?
# Prediction:  nine honey frames well-stocked Result Score:  0.9999878406524658 	|	 Answer:  nine honey frames well-stocked
#
# Sentence:  no queen seen, workers disoriented, drones dwindling, eggs few, with only two frames somewhat full
# Question:  what is the status of the queen in the hive?
# Prediction:  no queen seen Result Score:  0.9999942779541016 	|	 Answer:  no queen seen
# Question:  what is the egg count of the hive?
# Prediction:  eggs few Result Score:  0.9999353885650635 	|	 Answer:  eggs few
# Question:  what is the current health status of the hive?
# Prediction:  no queen seen Result Score:  0.9999938011169434 	|	 Answer:  no queen seen
#
# Sentence:  queen strong, worker activity high, adequate drones, good egg production, and nine honey frames ready for harvest
# Question:  describe the queen's activity or presence noted in the recent observations?
# Prediction:  queen strong Result Score:  0.9999256134033203 	|	 Answer:  queen strong
# Question:  what types of bee products have been collected recently?
# Prediction:  nine honey frames ready for harvest Result Score:  0.9998699426651001 	|	 Answer:  nine honey frames ready for harvest
#
# Sentence:  queen not found, minimal worker activity, down drone count, slow egg production, and seven frames needing attention
# Question:  describe the queen's activity or presence noted in the recent observations?
# Prediction:  queen not found Result Score:  0.9999728202819824 	|	 Answer:  queen not found
#
# Sentence:  queen active, brood present, forage adequate, four honey frames filled
# Question:  what is the status of the queen in the hive?
# Prediction:  queen active Result Score:  0.9999651908874512 	|	 Answer:  queen active
# Question:  describe the foraging behavior observed in the worker bees lately?
# Prediction:  forage adequate Result Score:  0.9999794960021973 	|	 Answer:  forage adequate
#
# Sentence:  queen robust, bustling workers, numerous drones, eggs filling up cells, and eight frames overflowing with honey
# Question:  can you estimate how many frames are ready for harvest?
# Prediction:  eight frames overflowing with honey Result Score:  0.9999669790267944 	|	 Answer:  eight frames overflowing with honey
#
# Sentence:  queen in decline, maintaining workers, few drones, low egg count, and five honey frames half full
# Question:  how many honey frames are currently filled in the hive?
# Prediction:  five honey frames half full Result Score:  0.9999939203262329 	|	 Answer:  five honey frames half full
# Question:  can you estimate how many frames are ready for harvest?
# Prediction:  five honey frames half full Result Score:  0.9999940395355225 	|	 Answer:  five honey frames half full
#
# Sentence:  queen absent, disorganized workers, scarce drones, few eggs laid, and seven honey frames poorly stocked
# Question:  what's the egg production like?
# Prediction:  few eggs Result Score:  0.991763710975647 	|	 Answer:  few eggs
# Question:  what is the status of drones in the hive?
# ...
# Question:  is there a queen currently present in the hive?
# Prediction:  queen robust Result Score:  0.9999443292617798 	|	 Answer:  queen robust
#
# Sentence:  queen absent, disorganized workers, minimal drones, scarce eggs, and five frames underdeveloped
# Question:  describe the queen's activity or presence noted in the recent observations?
# Prediction:  queen absent Result Score:  0.9999703168869019 	|	 Answer:  queen absent
#
# Sentence:  newly emerged queen, workers adjusting, drones building, good egg numbers, and five honey frames capped
# Question:  is there a queen currently present in the hive?
# Prediction:  newly emerged queen Result Score:  0.9999731779098511 	|	 Answer:  newly emerged queen
# Question:  are there any worker bees currently active in the hive?
# Prediction:  workers adjusting Result Score:  0.9999730587005615 	|	 Answer:  workers adjusting
# Question:  what is the status of workers in the hive?
# Prediction:  workers adjusting Result Score:  0.9999439716339111 	|	 Answer:  workers adjusting
#
# Sentence:  queen in decline, managing workers, few drones, dwindling eggs, with four frames only half full
# Question:  describe the queen's activity or presence noted in the recent observations?
# Prediction:  queen in decline Result Score:  0.9999799728393555 	|	 Answer:  queen in decline
#
# Sentence:  queen healthy, efficient workers, numerous drones, prolific eggs, and eleven frames fully stocked with honey
# Question:  can you estimate how many frames are ready for harvest?
# Prediction:  eleven frames fully stocked with honey Result Score:  0.9999748468399048 	|	 Answer:  eleven frames fully stocked with honey
# Question:  what types of bee products have been collected recently?
# Prediction:  eleven frames fully stocked with honey Result Score:  0.9999316930770874 	|	 Answer:  eleven frames fully stocked with honey
#
# Sentence:  queen absent, disorganized workers, scarce drones, few eggs laid, and eight honey frames poorly stocked
# Question:  what's the egg production like?
# Prediction:  few eggs Result Score:  0.9907422065734863 	|	 Answer:  few eggs
#
# Sentence:  queen productive, brood plentiful, forage high, nine honey frames ready
# Question:  how many honey frames are currently filled in the hive?
# Prediction:  nine honey frames ready Result Score:  0.9999945163726807 	|	 Answer:  nine honey frames ready
#
# Sentence:  queen vibrant, energetic workers, active drones, abundant eggs, and ten frames filled to capacity
# Question:  describe the queen's activity or presence noted in the recent observations?
# Prediction:  queen vibrant Result Score:  0.9999487400054932 	|	 Answer:  queen vibrant
# Question:  how many honey frames are currently filled in the hive?
# Prediction:  ten frames filled to capacity Result Score:  0.9999967813491821 	|	 Answer:  ten frames filled to capacity
# Question:  what's the egg production like?
# Prediction:  abundant eggs Result Score:  0.9999849796295166 	|	 Answer:  abundant eggs
#
# Sentence:  queen unspotted, brood fair, forage low, four honey frames stored
# Question:  describe the foraging behavior observed in the worker bees lately?
# Prediction:  forage low Result Score:  0.9999642372131348 	|	 Answer:  forage low
#
# Sentence:  queen visible, brood stable, good pollen harvest, seven honey frames capped
# Question:  can you list the bee products available from the latest harvest?
# Prediction:  honey frames capped Result Score:  0.9996682405471802 	|	 Answer:  honey frames capped
#
# Sentence:  queen reigning, strong brood, high nectar and pollen, nine honey frames full
# Question:  what's the egg production like?
# Prediction:  strong brood Result Score:  0.9999699592590332 	|	 Answer:  strong brood
#
# Sentence:  queen laying efficiently, active workers, healthy drones, plentiful eggs, and nine honey frames well-stocked
# Question:  is there a queen currently present in the hive?
# Prediction:  queen laying Result Score:  0.9998117089271545 	|	 Answer:  queen laying
#
# Sentence:  queen missing, sluggish workers, few drones, scarce eggs, and four honey frames underfilled
# Question:  can you list the bee products available from the latest harvest?
# Prediction:  honey frames underfilled Result Score:  0.9979244470596313 	|	 Answer:  honey frames underfilled
# Question:  what is the status of drones in the hive?
# Prediction:  few drones Result Score:  0.9999589920043945 	|	 Answer:  few drones
#
# Sentence:  the queen is missing, worker morale seems low, reduced pollen intake, minimal egg laying, and only two honey frames showing progress
# Question:  describe the queen's activity or presence noted in the recent observations?
# Prediction:  the queen is missing Result Score:  0.9979698061943054 	|	 Answer:  the queen is missing
#
# Sentence:  queen visible, workers thriving, drones active, robust egg count, and ten frames brimming with honey
# Question:  how many honey frames are currently filled in the hive?
# Prediction:  ten frames brimming with honey Result Score:  0.9999887943267822 	|	 Answer:  ten frames brimming with honey
# Question:  what is the status of the queen in the hive?
# Prediction:  queen visible Result Score:  0.9999792575836182 	|	 Answer:  queen visible
# Question:  what types of bee products have been collected recently?
# Prediction:  ten frames brimming with honey Result Score:  0.9999685287475586 	|	 Answer:  ten frames brimming with honey
#
# Sentence:  queen robust, workers tireless, drone count high, eggs numerous, rich in propolis, with all ten honey frames stocked
# Question:  can you estimate how many frames are ready for harvest?
# Prediction:  with all ten honey frames stocked Result Score:  0.9999672174453735 	|	 Answer:  with all ten honey frames stocked
#
# Sentence:  queen present, workers efficiently foraging, drones active, eggs numerous, and nine honey frames fully utilized
# Question:  describe the queen's activity or presence noted in the recent observations?
# Prediction:  queen present Result Score:  0.999962329864502 	|	 Answer:  queen present
# Question:  are there any worker bees currently active in the hive?
# Prediction:  workers efficiently foraging Result Score:  0.9995108842849731 	|	 Answer:  workers efficiently foraging
# Question:  how many honey frames are currently filled in the hive?
# Prediction:  nine honey frames fully utilized Result Score:  0.9999828338623047 	|	 Answer:  nine honey frames fully utilized
#
# Sentence:  queen absent, worker bees unsettled, drone numbers low, poor egg output, and four honey frames incomplete
# Question:  what is the status of workers in the hive?
# Prediction:  worker bees unsettled Result Score:  0.9999663829803467 	|	 Answer:  worker bees unsettled
#
# Sentence:  queen healthy, workers thriving, ample drones, numerous eggs, and eight frames densely packed with honey
# Question:  can you estimate how many frames are ready for harvest?
# Prediction:  eight frames densely packed with honey Result Score:  0.9999790191650391 	|	 Answer:  eight frames densely packed with honey
# Question:  what types of bee products have been collected recently?
# Prediction:  eight frames densely packed with honey Result Score:  0.999956488609314 	|	 Answer:  eight frames densely packed with honey
#
# Sentence:  queen productive, busy workers, ample drones, high egg count, and eight frames brimming with honey
# Question:  what is the status of workers in the hive?
# Prediction:  busy workers Result Score:  0.9999804496765137 	|	 Answer:  busy workers
#
# Sentence:  queen old, steady workers, fair drone numbers, moderate eggs, and seven honey frames well-stocked
# Question:  what is the status of workers in the hive?
# Prediction:  steady workers Result Score:  0.9999886751174927 	|	 Answer:  steady workers
# Question:  how many honey frames are currently filled in the hive?
# Prediction:  seven honey frames well-stocked Result Score:  0.9999744892120361 	|	 Answer:  seven honey frames well-stocked
# Question:  can you list the bee products available from the latest harvest?
# Prediction:  honey frames Result Score:  0.9999635219573975 	|	 Answer:  honey frames
# Question:  what types of bee products have been collected recently?
# Prediction:  honey frames Result Score:  0.9998987913131714 	|	 Answer:  honey frames
#
# Sentence:  a queen in her prime, workers in a frenzy of productivity, ample stores of propolis and honey, and a brood pattern so perfect it could be featured in a beekeeping manual
# Question:  is there a queen currently present in the hive?
# Prediction:  a queen in her prime Result Score:  0.9839121103286743 	|	 Answer:  a queen in her prime
#
# Sentence:  queen absent, workers listless, few drones, minimal egg laying, and four honey frames underutilized
# Question:  what is the status of workers in the hive?
# Prediction:  workers listless Result Score:  0.9999715089797974 	|	 Answer:  workers listless
#
# Sentence:  queen reigning well, worker bees busy, drones numerous, eggs filling cells, and propolis rich on eight honey frames
# Question:  how many honey frames are currently filled in the hive?
# Prediction:  propolis rich on eight honey frames Result Score:  0.9998347759246826 	|	 Answer:  propolis rich on eight honey frames
# Question:  can you estimate how many frames are ready for harvest?
# Prediction:  propolis rich on eight honey frames Result Score:  0.9999617338180542 	|	 Answer:  propolis rich on eight honey frames
#
# Sentence:  queen recently emerged, workers energized, drones abundant, eggs aplenty, and honey thick across nine frames
# Question:  how many honey frames are currently filled in the hive?
# Prediction:  honey thick across nine frames Result Score:  0.9998435974121094 	|	 Answer:  honey thick across nine frames
#
# Sentence:  queen productive, workers industrious, drones sufficient, high egg production, and six frames capped
# Question:  what's the egg production like?
# Prediction:  high egg production Result Score:  0.9999834299087524 	|	 Answer:  high egg production
#
# Sentence:  queen healthy, brood good, forage average, four honey frames ready
# Question:  can you list the bee products available from the latest harvest?
# Prediction:  honey frames ready Result Score:  0.991223931312561 	|	 Answer:  honey frames ready
# Question:  how many honey frames are currently filled in the hive?
# Prediction:  four honey frames ready Result Score:  0.9999910593032837 	|	 Answer:  four honey frames ready
# Question:  describe the foraging behavior observed in the worker bees lately?
# Prediction:  forage average Result Score:  0.9999477863311768 	|	 Answer:  forage average
#
# Sentence:  queen healthy, workers buzzing efficiently, drones ample, high egg count, and ten honey frames well-stocked
# Question:  what is the egg count of the hive?
# Prediction:  high egg count Result Score:  0.9999748468399048 	|	 Answer:  high egg count
#
# Sentence:  queen lethargic, workers maintaining, drone numbers low, egg presence moderate, with six frames half-filled with honey
# Question:  can you list the bee products available from the latest harvest?
# Prediction:  frames half-filled with honey Result Score:  0.9347282648086548 	|	 Answer:  frames half-filled with honey
# Question:  are there any worker bees currently active in the hive?
# Prediction:  workers maintaining Result Score:  0.9999823570251465 	|	 Answer:  workers maintaining
#
# Sentence:  queen laying well, workers vibrant, drones active, eggs numerous, and nine honey frames topped
# Question:  what is the status of drones in the hive?
# Prediction:  drones active Result Score:  0.9999668598175049 	|	 Answer:  drones active
#
# Sentence:  queen observed, workers efficient, drones active, high egg count, and eight honey frames fully utilized
# Question:  what is the current health status of the hive?
# Prediction:  queen observed Result Score:  0.9997679591178894 	|	 Answer:  queen observed
#
# Sentence:  queen in decline, brood okay, forage moderate, five honey frames completed
# Question:  what is the status of the queen in the hive?
# Prediction:  queen in decline Result Score:  0.9999924898147583 	|	 Answer:  queen in decline
#
# Sentence:  queen’s presence confirmed, strong brood development, a significant amount of propolis, bees actively foraging for nectar, and all ten honey frames being filled
# Question:  what types of bee products have been collected recently?
# Prediction:  all ten honey frames being filled Result Score:  0.9999079704284668 	|	 Answer:  all ten honey frames being filled
#
# Sentence:  queen visible and healthy, workers thriving, drones adequate, eggs abundant, and ten frames densely packed with honey
# Question:  what's the egg production like?
# Prediction:  eggs abundant Result Score:  0.999981164932251 	|	 Answer:  eggs abundant
#
# Sentence:  queen missing, sluggish workers, scant drones, eggs sparse, and four honey frames underfilled
# Question:  can you list the bee products available from the latest harvest?
# Prediction:  honey frames underfilled Result Score:  0.9987557530403137 	|	 Answer:  honey frames underfilled
#
# Sentence:  queen healthy, efficient workers, numerous drones, prolific eggs, and eight frames fully stocked with honey
# Question:  what is the egg count of the hive?
# Prediction:  prolific eggs Result Score:  0.9999804496765137 	|	 Answer:  prolific eggs
#
# Sentence:  queen in decline, managing workers, few drones, dwindling eggs, with seven frames only half full
# Question:  are there any worker bees currently active in the hive?
# Prediction:  managing workers Result Score:  0.9999856948852539 	|	 Answer:  managing workers
#
# Sentence:  queen missing, workers lethargic, drones declining, low egg count, and five honey frames barely utilized
# Question:  describe the queen's activity or presence noted in the recent observations?
# Prediction:  queen missing Result Score:  0.9999477863311768 	|	 Answer:  queen missing
#
# Sentence:  queen's health declining, workers sluggish, drones sparse, egg laying slow, three frames with scant honey
# Question:  what's the egg production like?
# Prediction:  egg laying slow Result Score:  0.9998767375946045 	|	 Answer:  egg laying slow
#
# Sentence:  strong queen, brood vibrant, high nectar intake, full ten honey frames
# Question:  describe the foraging behavior observed in the worker bees lately?
# Prediction:  high nectar intake Result Score:  0.9999576807022095 	|	 Answer:  high nectar intake
#
# Sentence:  queen not found, minimal worker activity, down drone count, slow egg production, and six frames needing attention
# Question:  what is the egg count of the hive?
# Prediction:  slow egg production Result Score:  0.9999828338623047 	|	 Answer:  low egg production
#
# Sentence:  no queen seen, worker bees disoriented, drones dwindling, eggs few, with only three frames somewhat full
# Question:  what is the current health status of the hive?
# Prediction:  no queen seen Result Score:  0.9999945163726807 	|	 Answer:  no queen seen
#
# Sentence:  active queen, strong brood, good nectar flow, eight honey frames filled
# Question:  is there a queen currently present in the hive?
# Prediction:  active queen Result Score:  0.9999445676803589 	|	 Answer:  active queen
#
# Sentence:  queen old, workers stable, drones sufficient, moderate egg laying, and six frames filled with honey
# Question:  how many honey frames are currently filled in the hive?
# Prediction:  six frames filled with honey Result Score:  0.9999842643737793 	|	 Answer:  six frames filled with honey
#
# Sentence:  queen missing, sluggish workers, scant drones, sparse eggs, and five honey frames only half filled
# Question:  how many honey frames are currently filled in the hive?
# Prediction:  five honey frames only half filled Result Score:  0.9997252821922302 	|	 Answer:  five honey frames only half filled
#
# Sentence:  queen aging, workers maintaining, drones sparse, egg laying reduced, and five honey frames partially filled
# Question:  what is the egg count of the hive?
# Prediction:  egg laying reduced Result Score:  0.9999309778213501 	|	 Answer:  egg laying reduced
#
# ----------------
# Score: 508.4992707371712
# Accuracy: 98.05%
# Correct Answers: 98.05%
# Wrong Answers: 1.95%
# Redundant Answers: 0.00%
# ----------------

# %%
import matplotlib.pyplot as plt

# Extracted data from your training log
epochs = [1, 2, 3, 4, 5, 6, 7, 8]
training_loss = [0.112300, 0.137700, 0.077500, 0.032000, 0.039700, 0.025000, 0.014500, 0.014700]
validation_loss = [0.204825, 0.125350, 0.102936, 0.102951, 0.089065, 0.084397, 0.084523, 0.081586]
start_accuracy = [0.962891, 0.972656, 0.974609, 0.982422, 0.982422, 0.984375, 0.984375, 0.984375]
end_accuracy = [0.931641, 0.960938, 0.964844, 0.966797, 0.974609, 0.980469, 0.978516, 0.980469]
overall_accuracy = [0.947266, 0.966797, 0.969727, 0.974609, 0.978516, 0.982422, 0.981445, 0.982422]

# Plot Training and Validation Loss
plt.figure(figsize=(12, 8))

plt.subplot(2, 1, 1)
plt.plot(epochs, training_loss, label='Training Loss', marker='o')
plt.plot(epochs, validation_loss, label='Validation Loss', marker='o')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Training and Validation Loss per Epoch')
plt.legend()

plt.subplot(2, 1, 2)
plt.plot(epochs, start_accuracy, label='Start Accuracy', marker='o')
plt.plot(epochs, end_accuracy, label='End Accuracy', marker='o')
plt.plot(epochs, overall_accuracy, label='Accuracy', marker='o')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.title('Accuracy per Epoch')
plt.legend()

plt.tight_layout()
plt.show()
